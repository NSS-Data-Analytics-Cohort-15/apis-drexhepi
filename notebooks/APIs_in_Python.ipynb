# %%
import requests
import matplotlib.pyplot as plt

# %% [markdown]
# # APIs
#
# An Application Programming Interface, or API, is a structured way to retrieve data from a website. Using an API is safer and easier than something like webscraping, since what you get back is already in a usable format. Many organizations use APIs like:
# - Government organizations ([US Government](https://www.data.gov/developers/apis))
# - Large companies ([Twitter API](https://developer.twitter.com/en/docs))
# - News organizations ([NYT API](https://developer.nytimes.com/))
# - And [many more](https://github.com/public-apis/public-apis)
#
# If you type `how to use an api in python` in google, you get back many articles walking through how to use an API. It is a well documented and useful tool to be familiar with.

# %% [markdown]
# ## Basic API Usage
#
# Let's start by using the Numbers API, an API which provides interesting facts about numbers.
#
# With any API, you should start by inspecting the documentation. For the Numbers API, the documentation is located here: http://numbersapi.com

# %% [markdown]
# We will be using the `requests` package to make a `GET` request to an API. Similar to webscraping, APIs require an endpoint to tell python where to send the request.
#
# When using an API, the first thing we need to know is the expected URL structure. In this case, it is http://numbersapi.com/number/type where number is the number for which we want an interesting fact and type indicates which type of fact we want. Note that type can be omitted, and it will default to trivia.

# %%
endpoint = 'http://numbersapi.com/8'

response = requests.get(endpoint)

# %% [markdown]
# Let's check the response. If all is well, we should have a 200 response.

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# To access the content of the response, we can look at the `text` attribute.

# %%
response.text
# Out:
# '8 is the number of principles of Yong in Chinese calligraphy.'

# %% [markdown]
# What if we want to be able to easily change the number that we want to retrieve. For this, we can make use of an f-string.

# %%
number = 150

endpoint = f'http://numbersapi.com/{number}'

response = requests.get(endpoint)

response.text
# Out:
# '150 is the number of estimated distinct phonemes in the Taa language.'

# %% [markdown]
# This API also allows for batch requests: http://numbersapi.com#batching

# %%
number_range = "15..20"

endpoint = f'http://numbersapi.com/{number_range}'

response = requests.get(endpoint)

# %% [markdown]
# We can look at the response as text.

# %%
response.text
# Out:
# '{\n "15": "15 is the approximate speed in miles per hour a penguin swims at.",\n "16": "16 is the minimum age for getting an adult job in most states and provinces across the globe.",\n "17": "17 is the number of the raka\'ahs that Muslims perform during Salah on a daily basis.",\n "18": "18 is the number of bronze monks the Shaolin temple had in Chinese folklore.",\n "19": "19 is the final year a person is a teenager.",\n "20": "20 is the number of ounces in Venti size coffees at Starbucks coffee shops."\n}'

# %% [markdown]
# However, it will be easier to work with as a json. We can use the `json` method to convert the results to a dictionary.

# %%
res = response.json()
res
# Out:
# {'15': '15 is the approximate speed in miles per hour a penguin swims at.',
#  '16': '16 is the minimum age for getting an adult job in most states and provinces across the globe.',
#  '17': "17 is the number of the raka'ahs that Muslims perform during Salah on a daily basis.",
#  '18': '18 is the number of bronze monks the Shaolin temple had in Chinese folklore.',
#  '19': '19 is the final year a person is a teenager.',
#  '20': '20 is the number of ounces in Venti size coffees at Starbucks coffee shops.'}

# %% [markdown]
# Then, we can access the individual entries by passing in the correct key.

# %%
res['15']
# Out:
# '15 is the approximate speed in miles per hour a penguin swims at.'

# %% [markdown]
# Finally, notice that we can ask for a fact about a random number.

# %%
endpoint = 'http://numbersapi.com/random'

response = requests.get(endpoint)

response.text
# Out:
# '500000 is the number of tons of dog excrement dumped annually on the streets of Paris.'

# %% [markdown]
# We can specify a minimum and maximum for these random numbers: http://numbersapi.com#min-and-max
#
# #### Parameters
#
# Parameters are specific to each API and indicate what information you want back. These can be compared to the various ways you slice a table or df to get just the subset you want. Some parameters are required, others are optional. Always look at the documentation to know what parameters you should include and what are possible values for each one. When using parameters for an API call, you can do the following:
#
# 1. Make an empty dictionary for the `params` variable
# 2. Look at the documentation to know what parameters you should include, add these as **keys** to the dictionary
# 3. Add the appropriate values for each parameter as the **values** for the dictionary
#
# For example, let's get a fact about a random number between 500 and 600

# %%
'http://numbersapi.com/random?min=10&max=20'

# %%
'http://numbersapi.com/random?min=500&max=600'

# %%
endpoint = 'http://numbersapi.com/random'

params = {
    'min': 10,
    'max': 20
}

response = requests.get(endpoint, params = params)

response.text
# Out:
# '20 is the number of questions in the popular party game Twenty Questions.'

# %% [markdown]
# ### NASA API and API Keys
#
# Now, let's work with the NASA API: https://api.nasa.gov/
#
# One of the main ways APIs maintain security is by the use of some form of authentication, such as an API key. An API key can be obtained in a number of ways, depending on the API, and is a way for the application to know who you are and provides you secure access to the data.
#
# To work with the NASA API, you'll need to create an API key.
#
# 1. Scroll down and enter your First Name, Last Name, and email to generate an API key
# 2. Copy the API key into the keys.json file.
#
# **DO NOT SHARE YOUR API KEYS OR PUT THEM IN A PUBLIC PLACE LIKE GITHUB**
#
# API keys should be stored securely on your computer and removed from any code or documents you share.

# %% [markdown]
# Now, we can safely load your key into a variable using the json library.

# %%
import json

# %%
with open('keys.json') as fi:
    credentials = json.load(fi)

# %%
api_key = credentials['api_key']

# %%
api_key
# Out:
# 'nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'

# %% [markdown]
# 1. Look at the different available APIs in the `Browse APIs` tab
# 2. Click on the **Asteroids - NeoWs**
# 3. Under **Neo - Feed**, copy the second line into the endpoint variable below as a string and delete the last `?`

# %%
endpoint = 'https://api.nasa.gov/neo/rest/v1/feed'

# %%
endpoint
# Out:
# 'https://api.nasa.gov/neo/rest/v1/feed'

# %% [markdown]
# Fill in the parameters dictionary below to retrieve information on all NeoWs between January 1, 2022 and January 7, 2022. (Be sure the include your api key as a parameter).

# %%
params = {
    'api_key' :api_key,
    
    

}

# %%
params = {'api_key' : api_key,
    'start_date' : '2022-01-01',
    'end_date'   : '2022-01-07'
         }

# %% [markdown]
# You now have all the pieces to make an API request

# %%
response = requests.get(endpoint, params = params)

# %% [markdown]
# See what was saved to `response`

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# This API returns the results as a json, so we'll access them using the `json` method.

# %%
res = response.json()
res
# Out:
# {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2022-1-7&end_date=2022-01-13&detailed=false&api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV',
#   'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2021-12-26&end_date=2022-1-1&detailed=false&api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV',
#   'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2022-1-1&end_date=2022-1-7&detailed=false&api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#  'element_count': 115,
#  'near_earth_objects': {'2022-01-07': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2494697?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '2494697',
#     'neo_reference_id': '2494697',
#     'name': '494697 (2004 SW55)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2494697',
#     'absolute_magnitude_h': 20.77,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1864468183,
#       'estimated_diameter_max': 0.41690776},
#      'meters': {'estimated_diameter_min': 186.44681832,
#       'estimated_diameter_max': 416.9077599521},
#      'miles': {'estimated_diameter_min': 0.1158526459,
#       'estimated_diameter_max': 0.2590543917},
#      'feet': {'estimated_diameter_min': 611.7021794171,
#       'estimated_diameter_max': 1367.8076551614}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 12:09',
#       'epoch_date_close_approach': 1641557340000,
#       'relative_velocity': {'kilometers_per_second': '10.0478001196',
#        'kilometers_per_hour': '36172.0804304837',
#        'miles_per_hour': '22475.9240874858'},
#       'miss_distance': {'astronomical': '0.1338706738',
#        'lunar': '52.0756921082',
#        'kilometers': '20026767.655944806',
#        'miles': '12444056.3828420828'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2496860?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '2496860',
#     'neo_reference_id': '2496860',
#     'name': '496860 (1999 XL136)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2496860',
#     'absolute_magnitude_h': 19.67,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3094246986,
#       'estimated_diameter_max': 0.69189466},
#      'meters': {'estimated_diameter_min': 309.4246986173,
#       'estimated_diameter_max': 691.8946600257},
#      'miles': {'estimated_diameter_min': 0.1922675344,
#       'estimated_diameter_max': 0.4299232768},
#      'feet': {'estimated_diameter_min': 1015.1729282116,
#       'estimated_diameter_max': 2269.9956763987}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 02:07',
#       'epoch_date_close_approach': 1641521220000,
#       'relative_velocity': {'kilometers_per_second': '16.7624360583',
#        'kilometers_per_hour': '60344.7698097014',
#        'miles_per_hour': '37495.8932187003'},
#       'miss_distance': {'astronomical': '0.0895472705',
#        'lunar': '34.8338882245',
#        'kilometers': '13396080.931113835',
#        'miles': '8323938.704427523'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3311963?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '3311963',
#     'neo_reference_id': '3311963',
#     'name': '(2006 AL4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3311963',
#     'absolute_magnitude_h': 24.92,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0275775053,
#       'estimated_diameter_max': 0.0616651765},
#      'meters': {'estimated_diameter_min': 27.5775052924,
#       'estimated_diameter_max': 61.6651764838},
#      'miles': {'estimated_diameter_min': 0.017135862,
#       'estimated_diameter_max': 0.0383169524},
#      'feet': {'estimated_diameter_min': 90.4773824637,
#       'estimated_diameter_max': 202.313577615}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 14:45',
#       'epoch_date_close_approach': 1641566700000,
#       'relative_velocity': {'kilometers_per_second': '9.4579600698',
#        'kilometers_per_hour': '34048.6562512758',
#        'miles_per_hour': '21156.510880133'},
#       'miss_distance': {'astronomical': '0.095183198',
#        'lunar': '37.026264022',
#        'kilometers': '14239203.68058826',
#        'miles': '8847830.887747588'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3401388?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '3401388',
#     'neo_reference_id': '3401388',
#     'name': '(2008 CO)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3401388',
#     'absolute_magnitude_h': 22.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0802703167,
#       'estimated_diameter_max': 0.1794898848},
#      'meters': {'estimated_diameter_min': 80.2703167283,
#       'estimated_diameter_max': 179.4898847799},
#      'miles': {'estimated_diameter_min': 0.049877647,
#       'estimated_diameter_max': 0.1115298092},
#      'feet': {'estimated_diameter_min': 263.3540659348,
#       'estimated_diameter_max': 588.8775935812}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 07:54',
#       'epoch_date_close_approach': 1641542040000,
#       'relative_velocity': {'kilometers_per_second': '4.4645655825',
#        'kilometers_per_hour': '16072.4360970133',
#        'miles_per_hour': '9986.7867515025'},
#       'miss_distance': {'astronomical': '0.2067861693',
#        'lunar': '80.4398198577',
#        'kilometers': '30934770.472739391',
#        'miles': '19221975.0369339558'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3827355?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '3827355',
#     'neo_reference_id': '3827355',
#     'name': '(2018 RH3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3827355',
#     'absolute_magnitude_h': 26.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0160160338,
#       'estimated_diameter_max': 0.0358129403},
#      'meters': {'estimated_diameter_min': 16.0160337979,
#       'estimated_diameter_max': 35.8129403019},
#      'miles': {'estimated_diameter_min': 0.0099518989,
#       'estimated_diameter_max': 0.0222531225},
#      'feet': {'estimated_diameter_min': 52.5460443254,
#       'estimated_diameter_max': 117.4965270602}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 06:02',
#       'epoch_date_close_approach': 1641535320000,
#       'relative_velocity': {'kilometers_per_second': '16.2331353604',
#        'kilometers_per_hour': '58439.287297512',
#        'miles_per_hour': '36311.9004877235'},
#       'miss_distance': {'astronomical': '0.2550666419',
#        'lunar': '99.2209236991',
#        'kilometers': '38157426.336292753',
#        'miles': '23709925.2815278714'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': True,
#     'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/3827355?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3976533?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '3976533',
#     'neo_reference_id': '3976533',
#     'name': '(2020 AP1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3976533',
#     'absolute_magnitude_h': 29.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0031956189,
#       'estimated_diameter_max': 0.007145621},
#      'meters': {'estimated_diameter_min': 3.1956188672,
#       'estimated_diameter_max': 7.1456210173},
#      'miles': {'estimated_diameter_min': 0.0019856649,
#       'estimated_diameter_max': 0.0044400817},
#      'feet': {'estimated_diameter_min': 10.4843142043,
#       'estimated_diameter_max': 23.4436392583}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 17:32',
#       'epoch_date_close_approach': 1641576720000,
#       'relative_velocity': {'kilometers_per_second': '5.6517941391',
#        'kilometers_per_hour': '20346.4589009102',
#        'miles_per_hour': '12642.4983098461'},
#       'miss_distance': {'astronomical': '0.0116565978',
#        'lunar': '4.5344165442',
#        'kilometers': '1743802.202326686',
#        'miles': '1083548.4437168268'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54191244?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54191244',
#     'neo_reference_id': '54191244',
#     'name': '(2021 QC3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54191244',
#     'absolute_magnitude_h': 24.24,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0377185489,
#       'estimated_diameter_max': 0.0843412394},
#      'meters': {'estimated_diameter_min': 37.7185489265,
#       'estimated_diameter_max': 84.3412394123},
#      'miles': {'estimated_diameter_min': 0.0234372125,
#       'estimated_diameter_max': 0.0524072003},
#      'feet': {'estimated_diameter_min': 123.74852406,
#       'estimated_diameter_max': 276.7101119134}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 13:43',
#       'epoch_date_close_approach': 1641562980000,
#       'relative_velocity': {'kilometers_per_second': '8.1228813159',
#        'kilometers_per_hour': '29242.3727372618',
#        'miles_per_hour': '18170.0732155503'},
#       'miss_distance': {'astronomical': '0.4076956724',
#        'lunar': '158.5936165636',
#        'kilometers': '60990404.199257788',
#        'miles': '37897679.8306539544'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235405?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54235405',
#     'neo_reference_id': '54235405',
#     'name': '(2022 AF)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235405',
#     'absolute_magnitude_h': 23.55,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0518268695,
#       'estimated_diameter_max': 0.1158884032},
#      'meters': {'estimated_diameter_min': 51.8268694616,
#       'estimated_diameter_max': 115.8884031771},
#      'miles': {'estimated_diameter_min': 0.0322037137,
#       'estimated_diameter_max': 0.072009693},
#      'feet': {'estimated_diameter_min': 170.0356664043,
#       'estimated_diameter_max': 380.2113086795}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 07:20',
#       'epoch_date_close_approach': 1641540000000,
#       'relative_velocity': {'kilometers_per_second': '9.7524815777',
#        'kilometers_per_hour': '35108.93367962',
#        'miles_per_hour': '21815.326041095'},
#       'miss_distance': {'astronomical': '0.0621069112',
#        'lunar': '24.1595884568',
#        'kilometers': '9291061.627799144',
#        'miles': '5773197.9887664272'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235666?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54235666',
#     'neo_reference_id': '54235666',
#     'name': '(2022 AR2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235666',
#     'absolute_magnitude_h': 27.66,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0078082728,
#       'estimated_diameter_max': 0.0174598287},
#      'meters': {'estimated_diameter_min': 7.8082727749,
#       'estimated_diameter_max': 17.4598287116},
#      'miles': {'estimated_diameter_min': 0.0048518343,
#       'estimated_diameter_max': 0.0108490312},
#      'feet': {'estimated_diameter_min': 25.6176936508,
#       'estimated_diameter_max': 57.2829044301}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 14:48',
#       'epoch_date_close_approach': 1641566880000,
#       'relative_velocity': {'kilometers_per_second': '11.6029565023',
#        'kilometers_per_hour': '41770.6434081241',
#        'miles_per_hour': '25954.653399898'},
#       'miss_distance': {'astronomical': '0.0043175257',
#        'lunar': '1.6795174973',
#        'kilometers': '645892.648390259',
#        'miles': '401339.0813692142'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54236614?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54236614',
#     'neo_reference_id': '54236614',
#     'name': '(2022 AZ5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54236614',
#     'absolute_magnitude_h': 22.89,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0702352248,
#       'estimated_diameter_max': 0.157050737},
#      'meters': {'estimated_diameter_min': 70.2352247696,
#       'estimated_diameter_max': 157.0507369998},
#      'miles': {'estimated_diameter_min': 0.0436421319,
#       'estimated_diameter_max': 0.0975867735},
#      'feet': {'estimated_diameter_min': 230.4305348332,
#       'estimated_diameter_max': 515.2583399786}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 09:11',
#       'epoch_date_close_approach': 1641546660000,
#       'relative_velocity': {'kilometers_per_second': '1.8564002385',
#        'kilometers_per_hour': '6683.0408586423',
#        'miles_per_hour': '4152.581693527'},
#       'miss_distance': {'astronomical': '0.2194725855',
#        'lunar': '85.3748357595',
#        'kilometers': '32832631.314192885',
#        'miles': '20401251.080056413'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54245585?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54245585',
#     'neo_reference_id': '54245585',
#     'name': '(2022 CV2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54245585',
#     'absolute_magnitude_h': 22.99,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0670741189,
#       'estimated_diameter_max': 0.1499822895},
#      'meters': {'estimated_diameter_min': 67.0741189325,
#       'estimated_diameter_max': 149.9822894641},
#      'miles': {'estimated_diameter_min': 0.0416779124,
#       'estimated_diameter_max': 0.0931946452},
#      'feet': {'estimated_diameter_min': 220.0594523586,
#       'estimated_diameter_max': 492.0678945652}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 14:20',
#       'epoch_date_close_approach': 1641565200000,
#       'relative_velocity': {'kilometers_per_second': '8.8178282495',
#        'kilometers_per_hour': '31744.1816982311',
#        'miles_per_hour': '19724.6000113259'},
#       'miss_distance': {'astronomical': '0.124719788',
#        'lunar': '48.515997532',
#        'kilometers': '18657814.63165156',
#        'miles': '11593428.417689128'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54245818?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54245818',
#     'neo_reference_id': '54245818',
#     'name': '(2022 CO3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54245818',
#     'absolute_magnitude_h': 25.71,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0191670368,
#       'estimated_diameter_max': 0.0428587972},
#      'meters': {'estimated_diameter_min': 19.1670367967,
#       'estimated_diameter_max': 42.8587972046},
#      'miles': {'estimated_diameter_min': 0.0119098408,
#       'estimated_diameter_max': 0.0266312137},
#      'feet': {'estimated_diameter_min': 62.883981004,
#       'estimated_diameter_max': 140.6128562208}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 14:21',
#       'epoch_date_close_approach': 1641565260000,
#       'relative_velocity': {'kilometers_per_second': '4.3330474572',
#        'kilometers_per_hour': '15598.9708459466',
#        'miles_per_hour': '9692.5938570272'},
#       'miss_distance': {'astronomical': '0.0708036214',
#        'lunar': '27.5426087246',
#        'kilometers': '10592070.949726418',
#        'miles': '6581607.6949558484'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54246945?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54246945',
#     'neo_reference_id': '54246945',
#     'name': '(2022 CN6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54246945',
#     'absolute_magnitude_h': 23.63,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.049952241,
#       'estimated_diameter_max': 0.1116966065},
#      'meters': {'estimated_diameter_min': 49.9522409906,
#       'estimated_diameter_max': 111.6966064835},
#      'miles': {'estimated_diameter_min': 0.0310388739,
#       'estimated_diameter_max': 0.0694050321},
#      'feet': {'estimated_diameter_min': 163.8853103317,
#       'estimated_diameter_max': 366.4586944153}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 18:12',
#       'epoch_date_close_approach': 1641579120000,
#       'relative_velocity': {'kilometers_per_second': '9.8502334438',
#        'kilometers_per_hour': '35460.8403976306',
#        'miles_per_hour': '22033.9871904055'},
#       'miss_distance': {'astronomical': '0.0858530959',
#        'lunar': '33.3968543051',
#        'kilometers': '12843440.279545733',
#        'miles': '7980543.7269797954'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54247545?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54247545',
#     'neo_reference_id': '54247545',
#     'name': '(2016 FH60)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54247545',
#     'absolute_magnitude_h': 23.14,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.06259721,
#       'estimated_diameter_max': 0.1399716167},
#      'meters': {'estimated_diameter_min': 62.597209966,
#       'estimated_diameter_max': 139.9716166857},
#      'miles': {'estimated_diameter_min': 0.038896091,
#       'estimated_diameter_max': 0.0869743034},
#      'feet': {'estimated_diameter_min': 205.3714303447,
#       'estimated_diameter_max': 459.2244788871}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 14:19',
#       'epoch_date_close_approach': 1641565140000,
#       'relative_velocity': {'kilometers_per_second': '8.8180100069',
#        'kilometers_per_hour': '31744.8360247963',
#        'miles_per_hour': '19725.0065844074'},
#       'miss_distance': {'astronomical': '0.1247267296',
#        'lunar': '48.5186978144',
#        'kilometers': '18658853.080225952',
#        'miles': '11594073.6797120576'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54278177?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54278177',
#     'neo_reference_id': '54278177',
#     'name': '(2022 JS)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54278177',
#     'absolute_magnitude_h': 26.02,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0166170902,
#       'estimated_diameter_max': 0.0371569432},
#      'meters': {'estimated_diameter_min': 16.617090174,
#       'estimated_diameter_max': 37.1569432173},
#      'miles': {'estimated_diameter_min': 0.0103253779,
#       'estimated_diameter_max': 0.023088247},
#      'feet': {'estimated_diameter_min': 54.5180141264,
#       'estimated_diameter_max': 121.9059855849}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 00:54',
#       'epoch_date_close_approach': 1641516840000,
#       'relative_velocity': {'kilometers_per_second': '3.3329790086',
#        'kilometers_per_hour': '11998.7244309963',
#        'miles_per_hour': '7455.5407443599'},
#       'miss_distance': {'astronomical': '0.2146381508',
#        'lunar': '83.4942406612',
#        'kilometers': '32109410.180418796',
#        'miles': '19951862.3059635448'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54282696?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54282696',
#     'neo_reference_id': '54282696',
#     'name': '(2022 LW2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54282696',
#     'absolute_magnitude_h': 25.9,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0175612318,
#       'estimated_diameter_max': 0.0392681082},
#      'meters': {'estimated_diameter_min': 17.561231848,
#       'estimated_diameter_max': 39.2681081809},
#      'miles': {'estimated_diameter_min': 0.0109120402,
#       'estimated_diameter_max': 0.0244000636},
#      'feet': {'estimated_diameter_min': 57.6155918963,
#       'estimated_diameter_max': 128.8323800441}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 20:00',
#       'epoch_date_close_approach': 1641585600000,
#       'relative_velocity': {'kilometers_per_second': '9.2659132128',
#        'kilometers_per_hour': '33357.2875659345',
#        'miles_per_hour': '20726.9212656219'},
#       'miss_distance': {'astronomical': '0.2811367573',
#        'lunar': '109.3621985897',
#        'kilometers': '42057460.070786951',
#        'miles': '26133293.8710478838'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54425755?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54425755',
#     'neo_reference_id': '54425755',
#     'name': '(2024 CU1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54425755',
#     'absolute_magnitude_h': 26.72,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0120380177,
#       'estimated_diameter_max': 0.0269178258},
#      'meters': {'estimated_diameter_min': 12.0380176738,
#       'estimated_diameter_max': 26.917825833},
#      'miles': {'estimated_diameter_min': 0.0074800751,
#       'estimated_diameter_max': 0.0167259564},
#      'feet': {'estimated_diameter_min': 39.494809905,
#       'estimated_diameter_max': 88.3130797061}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 12:43',
#       'epoch_date_close_approach': 1641559380000,
#       'relative_velocity': {'kilometers_per_second': '25.8115970732',
#        'kilometers_per_hour': '92921.7494633688',
#        'miles_per_hour': '57737.9614929471'},
#       'miss_distance': {'astronomical': '0.4700126636',
#        'lunar': '182.8349261404',
#        'kilometers': '70312893.347586532',
#        'miles': '43690405.9751448616'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54440311?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54440311',
#     'neo_reference_id': '54440311',
#     'name': '(2022 AY54)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54440311',
#     'absolute_magnitude_h': 30.26,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0023580607,
#       'estimated_diameter_max': 0.005272784},
#      'meters': {'estimated_diameter_min': 2.35806068,
#       'estimated_diameter_max': 5.2727839755},
#      'miles': {'estimated_diameter_min': 0.0014652305,
#       'estimated_diameter_max': 0.0032763551},
#      'feet': {'estimated_diameter_min': 7.7364198014,
#       'estimated_diameter_max': 17.2991605783}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 16:20',
#       'epoch_date_close_approach': 1641572400000,
#       'relative_velocity': {'kilometers_per_second': '17.8343002747',
#        'kilometers_per_hour': '64203.4809890064',
#        'miles_per_hour': '39893.5462845301'},
#       'miss_distance': {'astronomical': '0.0017304745',
#        'lunar': '0.6731545805',
#        'kilometers': '258875.299289315',
#        'miles': '160857.651909947'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54462805?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54462805',
#     'neo_reference_id': '54462805',
#     'name': '(2024 NM3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54462805',
#     'absolute_magnitude_h': 25.06,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0258556212,
#       'estimated_diameter_max': 0.0578149266},
#      'meters': {'estimated_diameter_min': 25.855621208,
#       'estimated_diameter_max': 57.8149266216},
#      'miles': {'estimated_diameter_min': 0.0160659332,
#       'estimated_diameter_max': 0.0359245188},
#      'feet': {'estimated_diameter_min': 84.828156284,
#       'estimated_diameter_max': 189.6815238571}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 04:42',
#       'epoch_date_close_approach': 1641530520000,
#       'relative_velocity': {'kilometers_per_second': '16.0786338517',
#        'kilometers_per_hour': '57883.0818662683',
#        'miles_per_hour': '35966.2960629599'},
#       'miss_distance': {'astronomical': '0.4069070197',
#        'lunar': '158.2868306633',
#        'kilometers': '60872423.435168039',
#        'miles': '37824369.9832713782'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54511081?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54511081',
#     'neo_reference_id': '54511081',
#     'name': '(2024 YJ7)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54511081',
#     'absolute_magnitude_h': 29.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0035039264,
#       'estimated_diameter_max': 0.0078350176},
#      'meters': {'estimated_diameter_min': 3.5039264111,
#       'estimated_diameter_max': 7.8350176433},
#      'miles': {'estimated_diameter_min': 0.0021772383,
#       'estimated_diameter_max': 0.0048684527},
#      'feet': {'estimated_diameter_min': 11.4958219265,
#       'estimated_diameter_max': 25.705439285}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-07',
#       'close_approach_date_full': '2022-Jan-07 22:03',
#       'epoch_date_close_approach': 1641592980000,
#       'relative_velocity': {'kilometers_per_second': '7.146525595',
#        'kilometers_per_hour': '25727.4921420703',
#        'miles_per_hour': '15986.0631034992'},
#       'miss_distance': {'astronomical': '0.0495388826',
#        'lunar': '19.2706253314',
#        'kilometers': '7410911.319140062',
#        'miles': '4604926.7604223756'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2022-01-03': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3313974?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '3313974',
#     'neo_reference_id': '3313974',
#     'name': '(2006 BV39)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3313974',
#     'absolute_magnitude_h': 29.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0040230458,
#       'estimated_diameter_max': 0.0089958039},
#      'meters': {'estimated_diameter_min': 4.0230457983,
#       'estimated_diameter_max': 8.9958038817},
#      'miles': {'estimated_diameter_min': 0.002499804,
#       'estimated_diameter_max': 0.0055897317},
#      'feet': {'estimated_diameter_min': 13.198969577,
#       'estimated_diameter_max': 29.5137932072}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 18:46',
#       'epoch_date_close_approach': 1641235560000,
#       'relative_velocity': {'kilometers_per_second': '22.7391653876',
#        'kilometers_per_hour': '81860.9953952192',
#        'miles_per_hour': '50865.239055435'},
#       'miss_distance': {'astronomical': '0.4926957707',
#        'lunar': '191.6586548023',
#        'kilometers': '73706237.854728409',
#        'miles': '45798932.4782096842'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3366282?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '3366282',
#     'neo_reference_id': '3366282',
#     'name': '(2007 BD)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3366282',
#     'absolute_magnitude_h': 25.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.022108281,
#       'estimated_diameter_max': 0.0494356193},
#      'meters': {'estimated_diameter_min': 22.1082810359,
#       'estimated_diameter_max': 49.435619262},
#      'miles': {'estimated_diameter_min': 0.0137374447,
#       'estimated_diameter_max': 0.0307178602},
#      'feet': {'estimated_diameter_min': 72.5337327539,
#       'estimated_diameter_max': 162.1903570994}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 21:43',
#       'epoch_date_close_approach': 1641246180000,
#       'relative_velocity': {'kilometers_per_second': '19.3262110391',
#        'kilometers_per_hour': '69574.3597407704',
#        'miles_per_hour': '43230.8014733693'},
#       'miss_distance': {'astronomical': '0.3772486341',
#        'lunar': '146.7497186649',
#        'kilometers': '56435592.121769367',
#        'miles': '35067450.8451645846'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3986680?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '3986680',
#     'neo_reference_id': '3986680',
#     'name': '(2020 AL3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3986680',
#     'absolute_magnitude_h': 26.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0152951935,
#       'estimated_diameter_max': 0.0342010925},
#      'meters': {'estimated_diameter_min': 15.2951935344,
#       'estimated_diameter_max': 34.201092472},
#      'miles': {'estimated_diameter_min': 0.0095039897,
#       'estimated_diameter_max': 0.021251567},
#      'feet': {'estimated_diameter_min': 50.1810827555,
#       'estimated_diameter_max': 112.2083122258}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 15:12',
#       'epoch_date_close_approach': 1641222720000,
#       'relative_velocity': {'kilometers_per_second': '23.2289584571',
#        'kilometers_per_hour': '83624.2504457378',
#        'miles_per_hour': '51960.8571727975'},
#       'miss_distance': {'astronomical': '0.3394091481',
#        'lunar': '132.0301586109',
#        'kilometers': '50774885.614274547',
#        'miles': '31550050.9254088686'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54106298?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54106298',
#     'neo_reference_id': '54106298',
#     'name': '(2021 BO)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54106298',
#     'absolute_magnitude_h': 32.95,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0006832112,
#       'estimated_diameter_max': 0.0015277067},
#      'meters': {'estimated_diameter_min': 0.6832111991,
#       'estimated_diameter_max': 1.5277066841},
#      'miles': {'estimated_diameter_min': 0.0004245276,
#       'estimated_diameter_max': 0.0009492726},
#      'feet': {'estimated_diameter_min': 2.2415066303,
#       'estimated_diameter_max': 5.0121611974}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 02:37',
#       'epoch_date_close_approach': 1641177420000,
#       'relative_velocity': {'kilometers_per_second': '19.5943065117',
#        'kilometers_per_hour': '70539.5034420685',
#        'miles_per_hour': '43830.5042359897'},
#       'miss_distance': {'astronomical': '0.4849352443',
#        'lunar': '188.6398100327',
#        'kilometers': '72545279.635209641',
#        'miles': '45077546.4917134058'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54160408?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54160408',
#     'neo_reference_id': '54160408',
#     'name': '(2021 LG7)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54160408',
#     'absolute_magnitude_h': 24.09,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0404161533,
#       'estimated_diameter_max': 0.0903732663},
#      'meters': {'estimated_diameter_min': 40.4161533403,
#       'estimated_diameter_max': 90.3732662579},
#      'miles': {'estimated_diameter_min': 0.0251134256,
#       'estimated_diameter_max': 0.0561553268},
#      'feet': {'estimated_diameter_min': 132.598932525,
#       'estimated_diameter_max': 296.5002268697}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 01:20',
#       'epoch_date_close_approach': 1641172800000,
#       'relative_velocity': {'kilometers_per_second': '9.2921585485',
#        'kilometers_per_hour': '33451.7707746505',
#        'miles_per_hour': '20785.629457171'},
#       'miss_distance': {'astronomical': '0.1898252773',
#        'lunar': '73.8420328697',
#        'kilometers': '28397457.156239351',
#        'miles': '17645361.6505950038'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54214719?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54214719',
#     'neo_reference_id': '54214719',
#     'name': '(2021 UW6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54214719',
#     'absolute_magnitude_h': 22.31,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0917392059,
#       'estimated_diameter_max': 0.2051351006},
#      'meters': {'estimated_diameter_min': 91.7392059155,
#       'estimated_diameter_max': 205.1351006288},
#      'miles': {'estimated_diameter_min': 0.0570040821,
#       'estimated_diameter_max': 0.1274650026},
#      'feet': {'estimated_diameter_min': 300.9816563357,
#       'estimated_diameter_max': 673.0154435471}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 19:32',
#       'epoch_date_close_approach': 1641238320000,
#       'relative_velocity': {'kilometers_per_second': '10.9229976895',
#        'kilometers_per_hour': '39322.7916823386',
#        'miles_per_hour': '24433.6535317287'},
#       'miss_distance': {'astronomical': '0.2821718381',
#        'lunar': '109.7648450209',
#        'kilometers': '42212305.953744847',
#        'miles': '26229510.6410870086'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235431?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54235431',
#     'neo_reference_id': '54235431',
#     'name': '(2022 AL)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235431',
#     'absolute_magnitude_h': 27.21,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0096062741,
#       'estimated_diameter_max': 0.021480282},
#      'meters': {'estimated_diameter_min': 9.606274149,
#       'estimated_diameter_max': 21.4802820076},
#      'miles': {'estimated_diameter_min': 0.0059690602,
#       'estimated_diameter_max': 0.0133472243},
#      'feet': {'estimated_diameter_min': 31.5166484789,
#       'estimated_diameter_max': 70.4733684217}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 12:45',
#       'epoch_date_close_approach': 1641213900000,
#       'relative_velocity': {'kilometers_per_second': '4.1088479046',
#        'kilometers_per_hour': '14791.8524564653',
#        'miles_per_hour': '9191.0818777409'},
#       'miss_distance': {'astronomical': '0.0187571805',
#        'lunar': '7.2965432145',
#        'kilometers': '2806034.250005535',
#        'miles': '1743588.831664983'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235463?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54235463',
#     'neo_reference_id': '54235463',
#     'name': '(2022 AU)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235463',
#     'absolute_magnitude_h': 29.13,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0039678475,
#       'estimated_diameter_max': 0.0088723768},
#      'meters': {'estimated_diameter_min': 3.9678475407,
#       'estimated_diameter_max': 8.8723768253},
#      'miles': {'estimated_diameter_min': 0.0024655054,
#       'estimated_diameter_max': 0.0055130377},
#      'feet': {'estimated_diameter_min': 13.0178729253,
#       'estimated_diameter_max': 29.1088487834}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 03:05',
#       'epoch_date_close_approach': 1641179100000,
#       'relative_velocity': {'kilometers_per_second': '7.2292378449',
#        'kilometers_per_hour': '26025.2562417962',
#        'miles_per_hour': '16171.0821353539'},
#       'miss_distance': {'astronomical': '0.0021291606',
#        'lunar': '0.8282434734',
#        'kilometers': '318517.890647922',
#        'miles': '197917.8396764436'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': True,
#     'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54235463?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235467?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54235467',
#     'neo_reference_id': '54235467',
#     'name': '(2022 AY)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235467',
#     'absolute_magnitude_h': 25.45,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0216050351,
#       'estimated_diameter_max': 0.0483103272},
#      'meters': {'estimated_diameter_min': 21.6050351196,
#       'estimated_diameter_max': 48.3103271838},
#      'miles': {'estimated_diameter_min': 0.0134247423,
#       'estimated_diameter_max': 0.0300186363},
#      'feet': {'estimated_diameter_min': 70.8826634219,
#       'estimated_diameter_max': 158.4984538377}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 11:13',
#       'epoch_date_close_approach': 1641208380000,
#       'relative_velocity': {'kilometers_per_second': '12.2317612796',
#        'kilometers_per_hour': '44034.3406065262',
#        'miles_per_hour': '27361.2268063162'},
#       'miss_distance': {'astronomical': '0.0518218428',
#        'lunar': '20.1586968492',
#        'kilometers': '7752437.302354836',
#        'miles': '4817141.1658792968'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235479?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54235479',
#     'neo_reference_id': '54235479',
#     'name': '(2022 AL1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235479',
#     'absolute_magnitude_h': 26.28,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0147419515,
#       'estimated_diameter_max': 0.0329640056},
#      'meters': {'estimated_diameter_min': 14.7419514504,
#       'estimated_diameter_max': 32.9640055641},
#      'miles': {'estimated_diameter_min': 0.0091602211,
#       'estimated_diameter_max': 0.0204828771},
#      'feet': {'estimated_diameter_min': 48.3659839966,
#       'estimated_diameter_max': 108.1496280151}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 20:50',
#       'epoch_date_close_approach': 1641243000000,
#       'relative_velocity': {'kilometers_per_second': '8.8316429811',
#        'kilometers_per_hour': '31793.9147319844',
#        'miles_per_hour': '19755.5021844377'},
#       'miss_distance': {'astronomical': '0.0437554459',
#        'lunar': '17.0208684551',
#        'kilometers': '6545721.507540233',
#        'miles': '4067322.7405238954'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235524?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54235524',
#     'neo_reference_id': '54235524',
#     'name': '(2022 AO1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235524',
#     'absolute_magnitude_h': 29.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0031956189,
#       'estimated_diameter_max': 0.007145621},
#      'meters': {'estimated_diameter_min': 3.1956188672,
#       'estimated_diameter_max': 7.1456210173},
#      'miles': {'estimated_diameter_min': 0.0019856649,
#       'estimated_diameter_max': 0.0044400817},
#      'feet': {'estimated_diameter_min': 10.4843142043,
#       'estimated_diameter_max': 23.4436392583}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 16:19',
#       'epoch_date_close_approach': 1641226740000,
#       'relative_velocity': {'kilometers_per_second': '14.0833111554',
#        'kilometers_per_hour': '50699.9201593154',
#        'miles_per_hour': '31502.9587234369'},
#       'miss_distance': {'astronomical': '0.0023236311',
#        'lunar': '0.9038924979',
#        'kilometers': '347610.263225757',
#        'miles': '215995.0017471666'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': True,
#     'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54235524?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235674?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54235674',
#     'neo_reference_id': '54235674',
#     'name': '(2022 AZ2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235674',
#     'absolute_magnitude_h': 27.75,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0074912618,
#       'estimated_diameter_max': 0.0167509707},
#      'meters': {'estimated_diameter_min': 7.4912618313,
#       'estimated_diameter_max': 16.750970692},
#      'miles': {'estimated_diameter_min': 0.0046548529,
#       'estimated_diameter_max': 0.0104085674},
#      'feet': {'estimated_diameter_min': 24.5776314666,
#       'estimated_diameter_max': 54.9572546853}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 19:34',
#       'epoch_date_close_approach': 1641238440000,
#       'relative_velocity': {'kilometers_per_second': '9.77217224',
#        'kilometers_per_hour': '35179.8200639127',
#        'miles_per_hour': '21859.3720836018'},
#       'miss_distance': {'astronomical': '0.0131463183',
#        'lunar': '5.1139178187',
#        'kilometers': '1966661.216022021',
#        'miles': '1222026.6135090498'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54243723?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54243723',
#     'neo_reference_id': '54243723',
#     'name': '(2022 BX5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54243723',
#     'absolute_magnitude_h': 29.04,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0041357566,
#       'estimated_diameter_max': 0.009247833},
#      'meters': {'estimated_diameter_min': 4.1357566488,
#       'estimated_diameter_max': 9.2478330051},
#      'miles': {'estimated_diameter_min': 0.0025698392,
#       'estimated_diameter_max': 0.0057463352},
#      'feet': {'estimated_diameter_min': 13.5687558437,
#       'estimated_diameter_max': 30.3406604365}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 20:44',
#       'epoch_date_close_approach': 1641242640000,
#       'relative_velocity': {'kilometers_per_second': '0.6500953649',
#        'kilometers_per_hour': '2340.343313525',
#        'miles_per_hour': '1454.1983216733'},
#       'miss_distance': {'astronomical': '0.0153014363',
#        'lunar': '5.9522587207',
#        'kilometers': '2289062.278420681',
#        'miles': '1422357.3442241578'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54330582?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54330582',
#     'neo_reference_id': '54330582',
#     'name': '(2022 WQ9)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54330582',
#     'absolute_magnitude_h': 28.73,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.004770402,
#       'estimated_diameter_max': 0.0106669431},
#      'meters': {'estimated_diameter_min': 4.7704019801,
#       'estimated_diameter_max': 10.6669431075},
#      'miles': {'estimated_diameter_min': 0.0029641894,
#       'estimated_diameter_max': 0.0066281291},
#      'feet': {'estimated_diameter_min': 15.6509256325,
#       'estimated_diameter_max': 34.996533625}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-03',
#       'close_approach_date_full': '2022-Jan-03 12:00',
#       'epoch_date_close_approach': 1641211200000,
#       'relative_velocity': {'kilometers_per_second': '5.1073246446',
#        'kilometers_per_hour': '18386.3687206673',
#        'miles_per_hour': '11424.5744975724'},
#       'miss_distance': {'astronomical': '0.1971316323',
#        'lunar': '76.6842049647',
#        'kilometers': '29490472.301703201',
#        'miles': '18324529.7685421338'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
# ...
#       'epoch_date_close_approach': 1641099720000,
#       'relative_velocity': {'kilometers_per_second': '20.4077209528',
#        'kilometers_per_hour': '73467.7954302229',
#        'miles_per_hour': '45650.0309994071'},
#       'miss_distance': {'astronomical': '0.495238863',
#        'lunar': '192.647917707',
#        'kilometers': '74086679.04602181',
#        'miles': '46035327.672688578'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3826839?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '3826839',
#     'neo_reference_id': '3826839',
#     'name': '(2018 PR23)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3826839',
#     'absolute_magnitude_h': 25.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.022108281,
#       'estimated_diameter_max': 0.0494356193},
#      'meters': {'estimated_diameter_min': 22.1082810359,
#       'estimated_diameter_max': 49.435619262},
#      'miles': {'estimated_diameter_min': 0.0137374447,
#       'estimated_diameter_max': 0.0307178602},
#      'feet': {'estimated_diameter_min': 72.5337327539,
#       'estimated_diameter_max': 162.1903570994}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 02:04',
#       'epoch_date_close_approach': 1641089040000,
#       'relative_velocity': {'kilometers_per_second': '8.4332699552',
#        'kilometers_per_hour': '30359.7718385923',
#        'miles_per_hour': '18864.3815627076'},
#       'miss_distance': {'astronomical': '0.4832391866',
#        'lunar': '187.9800435874',
#        'kilometers': '72291553.015892542',
#        'miles': '44919888.0811873996'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54053824?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54053824',
#     'neo_reference_id': '54053824',
#     'name': '(2020 RG2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54053824',
#     'absolute_magnitude_h': 27.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0101054342,
#       'estimated_diameter_max': 0.0225964377},
#      'meters': {'estimated_diameter_min': 10.1054341542,
#       'estimated_diameter_max': 22.5964377109},
#      'miles': {'estimated_diameter_min': 0.0062792237,
#       'estimated_diameter_max': 0.0140407711},
#      'feet': {'estimated_diameter_min': 33.1543125905,
#       'estimated_diameter_max': 74.1352966996}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 19:38',
#       'epoch_date_close_approach': 1641152280000,
#       'relative_velocity': {'kilometers_per_second': '14.9839822861',
#        'kilometers_per_hour': '53942.3362298765',
#        'miles_per_hour': '33517.6699757252'},
#       'miss_distance': {'astronomical': '0.394202746',
#        'lunar': '153.344868194',
#        'kilometers': '58971891.14975102',
#        'miles': '36643433.981843276'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54143421?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54143421',
#     'neo_reference_id': '54143421',
#     'name': '(2021 JG1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54143421',
#     'absolute_magnitude_h': 24.76,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0296862251,
#       'estimated_diameter_max': 0.0663804174},
#      'meters': {'estimated_diameter_min': 29.686225126,
#       'estimated_diameter_max': 66.3804173771},
#      'miles': {'estimated_diameter_min': 0.0184461594,
#       'estimated_diameter_max': 0.0412468663},
#      'feet': {'estimated_diameter_min': 97.3957548424,
#       'estimated_diameter_max': 217.7835285475}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 03:22',
#       'epoch_date_close_approach': 1641093720000,
#       'relative_velocity': {'kilometers_per_second': '9.0784070708',
#        'kilometers_per_hour': '32682.2654550162',
#        'miles_per_hour': '20307.4887767571'},
#       'miss_distance': {'astronomical': '0.4900141572',
#        'lunar': '190.6155071508',
#        'kilometers': '73305074.186965164',
#        'miles': '45549660.9339367032'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54203032?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54203032',
#     'neo_reference_id': '54203032',
#     'name': '(2021 TK3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54203032',
#     'absolute_magnitude_h': 20.05,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2597496533,
#       'estimated_diameter_max': 0.580817882},
#      'meters': {'estimated_diameter_min': 259.7496533301,
#       'estimated_diameter_max': 580.817881978},
#      'miles': {'estimated_diameter_min': 0.1614009018,
#       'estimated_diameter_max': 0.3609033881},
#      'feet': {'estimated_diameter_min': 852.1970526314,
#       'estimated_diameter_max': 1905.5705399087}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 09:23',
#       'epoch_date_close_approach': 1641115380000,
#       'relative_velocity': {'kilometers_per_second': '7.790798039',
#        'kilometers_per_hour': '28046.8729404888',
#        'miles_per_hour': '17427.2361334943'},
#       'miss_distance': {'astronomical': '0.3430354198',
#        'lunar': '133.4407783022',
#        'kilometers': '51317368.136635826',
#        'miles': '31887133.9340573588'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54231688?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54231688',
#     'neo_reference_id': '54231688',
#     'name': '(2021 YK)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54231688',
#     'absolute_magnitude_h': 27.35,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0090064777,
#       'estimated_diameter_max': 0.0201390963},
#      'meters': {'estimated_diameter_min': 9.0064776702,
#       'estimated_diameter_max': 20.1390963084},
#      'miles': {'estimated_diameter_min': 0.005596364,
#       'estimated_diameter_max': 0.0125138504},
#      'feet': {'estimated_diameter_min': 29.5488121994,
#       'estimated_diameter_max': 66.0731527323}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 16:03',
#       'epoch_date_close_approach': 1641139380000,
#       'relative_velocity': {'kilometers_per_second': '7.0444404315',
#        'kilometers_per_hour': '25359.9855533708',
#        'miles_per_hour': '15757.7088012042'},
#       'miss_distance': {'astronomical': '0.0012691966',
#        'lunar': '0.4937174774',
#        'kilometers': '189869.107971242',
#        'miles': '117979.1929254596'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': True,
#     'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54231688?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235436?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54235436',
#     'neo_reference_id': '54235436',
#     'name': '(2022 AQ)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235436',
#     'absolute_magnitude_h': 27.04,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.010388551,
#       'estimated_diameter_max': 0.0232295062},
#      'meters': {'estimated_diameter_min': 10.3885510102,
#       'estimated_diameter_max': 23.2295062464},
#      'miles': {'estimated_diameter_min': 0.0064551443,
#       'estimated_diameter_max': 0.0144341415},
#      'feet': {'estimated_diameter_min': 34.0831736962,
#       'estimated_diameter_max': 76.2122932736}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 15:58',
#       'epoch_date_close_approach': 1641139080000,
#       'relative_velocity': {'kilometers_per_second': '11.4430529094',
#        'kilometers_per_hour': '41194.9904738353',
#        'miles_per_hour': '25596.965053034'},
#       'miss_distance': {'astronomical': '0.0192982031',
#        'lunar': '7.5070010059',
#        'kilometers': '2886970.078587397',
#        'miles': '1793880.0235121986'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235525?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54235525',
#     'neo_reference_id': '54235525',
#     'name': '(2022 AP1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235525',
#     'absolute_magnitude_h': 28.39,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0055789822,
#       'estimated_diameter_max': 0.0124749835},
#      'meters': {'estimated_diameter_min': 5.5789822107,
#       'estimated_diameter_max': 12.4749834683},
#      'miles': {'estimated_diameter_min': 0.0034666178,
#       'estimated_diameter_max': 0.007751593},
#      'feet': {'estimated_diameter_min': 18.3037479961,
#       'estimated_diameter_max': 40.9284247622}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 16:56',
#       'epoch_date_close_approach': 1641142560000,
#       'relative_velocity': {'kilometers_per_second': '10.640214595',
#        'kilometers_per_hour': '38304.772541869',
#        'miles_per_hour': '23801.0960274741'},
#       'miss_distance': {'astronomical': '0.0012072168',
#        'lunar': '0.4696073352',
#        'kilometers': '180597.061908216',
#        'miles': '112217.8106607408'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': True,
#     'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54235525?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235670?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54235670',
#     'neo_reference_id': '54235670',
#     'name': '(2022 AV2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235670',
#     'absolute_magnitude_h': 24.81,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0290104841,
#       'estimated_diameter_max': 0.0648694146},
#      'meters': {'estimated_diameter_min': 29.0104841428,
#       'estimated_diameter_max': 64.8694146035},
#      'miles': {'estimated_diameter_min': 0.0180262735,
#       'estimated_diameter_max': 0.040307973},
#      'feet': {'estimated_diameter_min': 95.1787567951,
#       'estimated_diameter_max': 212.8261702077}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 09:40',
#       'epoch_date_close_approach': 1641116400000,
#       'relative_velocity': {'kilometers_per_second': '11.4458122646',
#        'kilometers_per_hour': '41204.9241523926',
#        'miles_per_hour': '25603.1374545797'},
#       'miss_distance': {'astronomical': '0.0663840677',
#        'lunar': '25.8234023353',
#        'kilometers': '9930915.129855799',
#        'miles': '6170784.5186120662'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54240279?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54240279',
#     'neo_reference_id': '54240279',
#     'name': '(2022 BF2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54240279',
#     'absolute_magnitude_h': 23.02,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0661538275,
#       'estimated_diameter_max': 0.1479244553},
#      'meters': {'estimated_diameter_min': 66.1538275199,
#       'estimated_diameter_max': 147.9244553064},
#      'miles': {'estimated_diameter_min': 0.04110607,
#       'estimated_diameter_max': 0.0919159667},
#      'feet': {'estimated_diameter_min': 217.0401234805,
#       'estimated_diameter_max': 485.3164699474}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 09:44',
#       'epoch_date_close_approach': 1641116640000,
#       'relative_velocity': {'kilometers_per_second': '13.6716305429',
#        'kilometers_per_hour': '49217.8699543345',
#        'miles_per_hour': '30582.0703613475'},
#       'miss_distance': {'astronomical': '0.1396774323',
#        'lunar': '54.3345211647',
#        'kilometers': '20895446.359149201',
#        'miles': '12983828.2994569338'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54374712?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54374712',
#     'neo_reference_id': '54374712',
#     'name': '(2023 NC)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54374712',
#     'absolute_magnitude_h': 23.73,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0477040198,
#       'estimated_diameter_max': 0.1066694311},
#      'meters': {'estimated_diameter_min': 47.7040198012,
#       'estimated_diameter_max': 106.6694310755},
#      'miles': {'estimated_diameter_min': 0.0296418945,
#       'estimated_diameter_max': 0.0662812911},
#      'feet': {'estimated_diameter_min': 156.5092563246,
#       'estimated_diameter_max': 349.9653362497}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 12:35',
#       'epoch_date_close_approach': 1641126900000,
#       'relative_velocity': {'kilometers_per_second': '12.9390279932',
#        'kilometers_per_hour': '46580.5007753576',
#        'miles_per_hour': '28943.3117178882'},
#       'miss_distance': {'astronomical': '0.2914198022',
#        'lunar': '113.3623030558',
#        'kilometers': '43595781.684941314',
#        'miles': '27089162.5978615732'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54469019?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#     'id': '54469019',
#     'neo_reference_id': '54469019',
#     'name': '(2024 RT5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54469019',
#     'absolute_magnitude_h': 23.92,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0437074004,
#       'estimated_diameter_max': 0.0977327184},
#      'meters': {'estimated_diameter_min': 43.7074004031,
#       'estimated_diameter_max': 97.732718421},
#      'miles': {'estimated_diameter_min': 0.0271585111,
#       'estimated_diameter_max': 0.060728277},
#      'feet': {'estimated_diameter_min': 143.3969875384,
#       'estimated_diameter_max': 320.6454119044}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2022-01-02',
#       'close_approach_date_full': '2022-Jan-02 13:22',
#       'epoch_date_close_approach': 1641129720000,
#       'relative_velocity': {'kilometers_per_second': '16.2228330993',
#        'kilometers_per_hour': '58402.199157368',
#        'miles_per_hour': '36288.8553597546'},
#       'miss_distance': {'astronomical': '0.4625825018',
#        'lunar': '179.9445932002',
#        'kilometers': '69201356.968551166',
#        'miles': '42999729.2963154508'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}]}}

# %%
res.keys()
# Out:
# dict_keys(['links', 'element_count', 'near_earth_objects'])

# %% [markdown]
# The information that we're interested in is located under `near_earth_objects`.

# %%
res['near_earth_objects']
# Out:
# {'2022-01-07': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2494697?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '2494697',
#    'neo_reference_id': '2494697',
#    'name': '494697 (2004 SW55)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2494697',
#    'absolute_magnitude_h': 20.77,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1864468183,
#      'estimated_diameter_max': 0.41690776},
#     'meters': {'estimated_diameter_min': 186.44681832,
#      'estimated_diameter_max': 416.9077599521},
#     'miles': {'estimated_diameter_min': 0.1158526459,
#      'estimated_diameter_max': 0.2590543917},
#     'feet': {'estimated_diameter_min': 611.7021794171,
#      'estimated_diameter_max': 1367.8076551614}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 12:09',
#      'epoch_date_close_approach': 1641557340000,
#      'relative_velocity': {'kilometers_per_second': '10.0478001196',
#       'kilometers_per_hour': '36172.0804304837',
#       'miles_per_hour': '22475.9240874858'},
#      'miss_distance': {'astronomical': '0.1338706738',
#       'lunar': '52.0756921082',
#       'kilometers': '20026767.655944806',
#       'miles': '12444056.3828420828'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2496860?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '2496860',
#    'neo_reference_id': '2496860',
#    'name': '496860 (1999 XL136)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2496860',
#    'absolute_magnitude_h': 19.67,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3094246986,
#      'estimated_diameter_max': 0.69189466},
#     'meters': {'estimated_diameter_min': 309.4246986173,
#      'estimated_diameter_max': 691.8946600257},
#     'miles': {'estimated_diameter_min': 0.1922675344,
#      'estimated_diameter_max': 0.4299232768},
#     'feet': {'estimated_diameter_min': 1015.1729282116,
#      'estimated_diameter_max': 2269.9956763987}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 02:07',
#      'epoch_date_close_approach': 1641521220000,
#      'relative_velocity': {'kilometers_per_second': '16.7624360583',
#       'kilometers_per_hour': '60344.7698097014',
#       'miles_per_hour': '37495.8932187003'},
#      'miss_distance': {'astronomical': '0.0895472705',
#       'lunar': '34.8338882245',
#       'kilometers': '13396080.931113835',
#       'miles': '8323938.704427523'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3311963?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '3311963',
#    'neo_reference_id': '3311963',
#    'name': '(2006 AL4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3311963',
#    'absolute_magnitude_h': 24.92,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0275775053,
#      'estimated_diameter_max': 0.0616651765},
#     'meters': {'estimated_diameter_min': 27.5775052924,
#      'estimated_diameter_max': 61.6651764838},
#     'miles': {'estimated_diameter_min': 0.017135862,
#      'estimated_diameter_max': 0.0383169524},
#     'feet': {'estimated_diameter_min': 90.4773824637,
#      'estimated_diameter_max': 202.313577615}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 14:45',
#      'epoch_date_close_approach': 1641566700000,
#      'relative_velocity': {'kilometers_per_second': '9.4579600698',
#       'kilometers_per_hour': '34048.6562512758',
#       'miles_per_hour': '21156.510880133'},
#      'miss_distance': {'astronomical': '0.095183198',
#       'lunar': '37.026264022',
#       'kilometers': '14239203.68058826',
#       'miles': '8847830.887747588'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3401388?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '3401388',
#    'neo_reference_id': '3401388',
#    'name': '(2008 CO)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3401388',
#    'absolute_magnitude_h': 22.6,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0802703167,
#      'estimated_diameter_max': 0.1794898848},
#     'meters': {'estimated_diameter_min': 80.2703167283,
#      'estimated_diameter_max': 179.4898847799},
#     'miles': {'estimated_diameter_min': 0.049877647,
#      'estimated_diameter_max': 0.1115298092},
#     'feet': {'estimated_diameter_min': 263.3540659348,
#      'estimated_diameter_max': 588.8775935812}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 07:54',
#      'epoch_date_close_approach': 1641542040000,
#      'relative_velocity': {'kilometers_per_second': '4.4645655825',
#       'kilometers_per_hour': '16072.4360970133',
#       'miles_per_hour': '9986.7867515025'},
#      'miss_distance': {'astronomical': '0.2067861693',
#       'lunar': '80.4398198577',
#       'kilometers': '30934770.472739391',
#       'miles': '19221975.0369339558'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3827355?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '3827355',
#    'neo_reference_id': '3827355',
#    'name': '(2018 RH3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3827355',
#    'absolute_magnitude_h': 26.1,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0160160338,
#      'estimated_diameter_max': 0.0358129403},
#     'meters': {'estimated_diameter_min': 16.0160337979,
#      'estimated_diameter_max': 35.8129403019},
#     'miles': {'estimated_diameter_min': 0.0099518989,
#      'estimated_diameter_max': 0.0222531225},
#     'feet': {'estimated_diameter_min': 52.5460443254,
#      'estimated_diameter_max': 117.4965270602}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 06:02',
#      'epoch_date_close_approach': 1641535320000,
#      'relative_velocity': {'kilometers_per_second': '16.2331353604',
#       'kilometers_per_hour': '58439.287297512',
#       'miles_per_hour': '36311.9004877235'},
#      'miss_distance': {'astronomical': '0.2550666419',
#       'lunar': '99.2209236991',
#       'kilometers': '38157426.336292753',
#       'miles': '23709925.2815278714'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
#    'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/3827355?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3976533?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '3976533',
#    'neo_reference_id': '3976533',
#    'name': '(2020 AP1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3976533',
#    'absolute_magnitude_h': 29.6,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0031956189,
#      'estimated_diameter_max': 0.007145621},
#     'meters': {'estimated_diameter_min': 3.1956188672,
#      'estimated_diameter_max': 7.1456210173},
#     'miles': {'estimated_diameter_min': 0.0019856649,
#      'estimated_diameter_max': 0.0044400817},
#     'feet': {'estimated_diameter_min': 10.4843142043,
#      'estimated_diameter_max': 23.4436392583}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 17:32',
#      'epoch_date_close_approach': 1641576720000,
#      'relative_velocity': {'kilometers_per_second': '5.6517941391',
#       'kilometers_per_hour': '20346.4589009102',
#       'miles_per_hour': '12642.4983098461'},
#      'miss_distance': {'astronomical': '0.0116565978',
#       'lunar': '4.5344165442',
#       'kilometers': '1743802.202326686',
#       'miles': '1083548.4437168268'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54191244?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54191244',
#    'neo_reference_id': '54191244',
#    'name': '(2021 QC3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54191244',
#    'absolute_magnitude_h': 24.24,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0377185489,
#      'estimated_diameter_max': 0.0843412394},
#     'meters': {'estimated_diameter_min': 37.7185489265,
#      'estimated_diameter_max': 84.3412394123},
#     'miles': {'estimated_diameter_min': 0.0234372125,
#      'estimated_diameter_max': 0.0524072003},
#     'feet': {'estimated_diameter_min': 123.74852406,
#      'estimated_diameter_max': 276.7101119134}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 13:43',
#      'epoch_date_close_approach': 1641562980000,
#      'relative_velocity': {'kilometers_per_second': '8.1228813159',
#       'kilometers_per_hour': '29242.3727372618',
#       'miles_per_hour': '18170.0732155503'},
#      'miss_distance': {'astronomical': '0.4076956724',
#       'lunar': '158.5936165636',
#       'kilometers': '60990404.199257788',
#       'miles': '37897679.8306539544'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235405?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54235405',
#    'neo_reference_id': '54235405',
#    'name': '(2022 AF)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235405',
#    'absolute_magnitude_h': 23.55,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0518268695,
#      'estimated_diameter_max': 0.1158884032},
#     'meters': {'estimated_diameter_min': 51.8268694616,
#      'estimated_diameter_max': 115.8884031771},
#     'miles': {'estimated_diameter_min': 0.0322037137,
#      'estimated_diameter_max': 0.072009693},
#     'feet': {'estimated_diameter_min': 170.0356664043,
#      'estimated_diameter_max': 380.2113086795}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 07:20',
#      'epoch_date_close_approach': 1641540000000,
#      'relative_velocity': {'kilometers_per_second': '9.7524815777',
#       'kilometers_per_hour': '35108.93367962',
#       'miles_per_hour': '21815.326041095'},
#      'miss_distance': {'astronomical': '0.0621069112',
#       'lunar': '24.1595884568',
#       'kilometers': '9291061.627799144',
#       'miles': '5773197.9887664272'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235666?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54235666',
#    'neo_reference_id': '54235666',
#    'name': '(2022 AR2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235666',
#    'absolute_magnitude_h': 27.66,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0078082728,
#      'estimated_diameter_max': 0.0174598287},
#     'meters': {'estimated_diameter_min': 7.8082727749,
#      'estimated_diameter_max': 17.4598287116},
#     'miles': {'estimated_diameter_min': 0.0048518343,
#      'estimated_diameter_max': 0.0108490312},
#     'feet': {'estimated_diameter_min': 25.6176936508,
#      'estimated_diameter_max': 57.2829044301}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 14:48',
#      'epoch_date_close_approach': 1641566880000,
#      'relative_velocity': {'kilometers_per_second': '11.6029565023',
#       'kilometers_per_hour': '41770.6434081241',
#       'miles_per_hour': '25954.653399898'},
#      'miss_distance': {'astronomical': '0.0043175257',
#       'lunar': '1.6795174973',
#       'kilometers': '645892.648390259',
#       'miles': '401339.0813692142'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54236614?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54236614',
#    'neo_reference_id': '54236614',
#    'name': '(2022 AZ5)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54236614',
#    'absolute_magnitude_h': 22.89,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0702352248,
#      'estimated_diameter_max': 0.157050737},
#     'meters': {'estimated_diameter_min': 70.2352247696,
#      'estimated_diameter_max': 157.0507369998},
#     'miles': {'estimated_diameter_min': 0.0436421319,
#      'estimated_diameter_max': 0.0975867735},
#     'feet': {'estimated_diameter_min': 230.4305348332,
#      'estimated_diameter_max': 515.2583399786}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 09:11',
#      'epoch_date_close_approach': 1641546660000,
#      'relative_velocity': {'kilometers_per_second': '1.8564002385',
#       'kilometers_per_hour': '6683.0408586423',
#       'miles_per_hour': '4152.581693527'},
#      'miss_distance': {'astronomical': '0.2194725855',
#       'lunar': '85.3748357595',
#       'kilometers': '32832631.314192885',
#       'miles': '20401251.080056413'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54245585?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54245585',
#    'neo_reference_id': '54245585',
#    'name': '(2022 CV2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54245585',
#    'absolute_magnitude_h': 22.99,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0670741189,
#      'estimated_diameter_max': 0.1499822895},
#     'meters': {'estimated_diameter_min': 67.0741189325,
#      'estimated_diameter_max': 149.9822894641},
#     'miles': {'estimated_diameter_min': 0.0416779124,
#      'estimated_diameter_max': 0.0931946452},
#     'feet': {'estimated_diameter_min': 220.0594523586,
#      'estimated_diameter_max': 492.0678945652}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 14:20',
#      'epoch_date_close_approach': 1641565200000,
#      'relative_velocity': {'kilometers_per_second': '8.8178282495',
#       'kilometers_per_hour': '31744.1816982311',
#       'miles_per_hour': '19724.6000113259'},
#      'miss_distance': {'astronomical': '0.124719788',
#       'lunar': '48.515997532',
#       'kilometers': '18657814.63165156',
#       'miles': '11593428.417689128'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54245818?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54245818',
#    'neo_reference_id': '54245818',
#    'name': '(2022 CO3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54245818',
#    'absolute_magnitude_h': 25.71,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0191670368,
#      'estimated_diameter_max': 0.0428587972},
#     'meters': {'estimated_diameter_min': 19.1670367967,
#      'estimated_diameter_max': 42.8587972046},
#     'miles': {'estimated_diameter_min': 0.0119098408,
#      'estimated_diameter_max': 0.0266312137},
#     'feet': {'estimated_diameter_min': 62.883981004,
#      'estimated_diameter_max': 140.6128562208}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 14:21',
#      'epoch_date_close_approach': 1641565260000,
#      'relative_velocity': {'kilometers_per_second': '4.3330474572',
#       'kilometers_per_hour': '15598.9708459466',
#       'miles_per_hour': '9692.5938570272'},
#      'miss_distance': {'astronomical': '0.0708036214',
#       'lunar': '27.5426087246',
#       'kilometers': '10592070.949726418',
#       'miles': '6581607.6949558484'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54246945?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54246945',
#    'neo_reference_id': '54246945',
#    'name': '(2022 CN6)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54246945',
#    'absolute_magnitude_h': 23.63,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.049952241,
#      'estimated_diameter_max': 0.1116966065},
#     'meters': {'estimated_diameter_min': 49.9522409906,
#      'estimated_diameter_max': 111.6966064835},
#     'miles': {'estimated_diameter_min': 0.0310388739,
#      'estimated_diameter_max': 0.0694050321},
#     'feet': {'estimated_diameter_min': 163.8853103317,
#      'estimated_diameter_max': 366.4586944153}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 18:12',
#      'epoch_date_close_approach': 1641579120000,
#      'relative_velocity': {'kilometers_per_second': '9.8502334438',
#       'kilometers_per_hour': '35460.8403976306',
#       'miles_per_hour': '22033.9871904055'},
#      'miss_distance': {'astronomical': '0.0858530959',
#       'lunar': '33.3968543051',
#       'kilometers': '12843440.279545733',
#       'miles': '7980543.7269797954'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54247545?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54247545',
#    'neo_reference_id': '54247545',
#    'name': '(2016 FH60)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54247545',
#    'absolute_magnitude_h': 23.14,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.06259721,
#      'estimated_diameter_max': 0.1399716167},
#     'meters': {'estimated_diameter_min': 62.597209966,
#      'estimated_diameter_max': 139.9716166857},
#     'miles': {'estimated_diameter_min': 0.038896091,
#      'estimated_diameter_max': 0.0869743034},
#     'feet': {'estimated_diameter_min': 205.3714303447,
#      'estimated_diameter_max': 459.2244788871}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 14:19',
#      'epoch_date_close_approach': 1641565140000,
#      'relative_velocity': {'kilometers_per_second': '8.8180100069',
#       'kilometers_per_hour': '31744.8360247963',
#       'miles_per_hour': '19725.0065844074'},
#      'miss_distance': {'astronomical': '0.1247267296',
#       'lunar': '48.5186978144',
#       'kilometers': '18658853.080225952',
#       'miles': '11594073.6797120576'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54278177?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54278177',
#    'neo_reference_id': '54278177',
#    'name': '(2022 JS)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54278177',
#    'absolute_magnitude_h': 26.02,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0166170902,
#      'estimated_diameter_max': 0.0371569432},
#     'meters': {'estimated_diameter_min': 16.617090174,
#      'estimated_diameter_max': 37.1569432173},
#     'miles': {'estimated_diameter_min': 0.0103253779,
#      'estimated_diameter_max': 0.023088247},
#     'feet': {'estimated_diameter_min': 54.5180141264,
#      'estimated_diameter_max': 121.9059855849}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 00:54',
#      'epoch_date_close_approach': 1641516840000,
#      'relative_velocity': {'kilometers_per_second': '3.3329790086',
#       'kilometers_per_hour': '11998.7244309963',
#       'miles_per_hour': '7455.5407443599'},
#      'miss_distance': {'astronomical': '0.2146381508',
#       'lunar': '83.4942406612',
#       'kilometers': '32109410.180418796',
#       'miles': '19951862.3059635448'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54282696?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54282696',
#    'neo_reference_id': '54282696',
#    'name': '(2022 LW2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54282696',
#    'absolute_magnitude_h': 25.9,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0175612318,
#      'estimated_diameter_max': 0.0392681082},
#     'meters': {'estimated_diameter_min': 17.561231848,
#      'estimated_diameter_max': 39.2681081809},
#     'miles': {'estimated_diameter_min': 0.0109120402,
#      'estimated_diameter_max': 0.0244000636},
#     'feet': {'estimated_diameter_min': 57.6155918963,
#      'estimated_diameter_max': 128.8323800441}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 20:00',
#      'epoch_date_close_approach': 1641585600000,
#      'relative_velocity': {'kilometers_per_second': '9.2659132128',
#       'kilometers_per_hour': '33357.2875659345',
#       'miles_per_hour': '20726.9212656219'},
#      'miss_distance': {'astronomical': '0.2811367573',
#       'lunar': '109.3621985897',
#       'kilometers': '42057460.070786951',
#       'miles': '26133293.8710478838'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54425755?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54425755',
#    'neo_reference_id': '54425755',
#    'name': '(2024 CU1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54425755',
#    'absolute_magnitude_h': 26.72,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0120380177,
#      'estimated_diameter_max': 0.0269178258},
#     'meters': {'estimated_diameter_min': 12.0380176738,
#      'estimated_diameter_max': 26.917825833},
#     'miles': {'estimated_diameter_min': 0.0074800751,
#      'estimated_diameter_max': 0.0167259564},
#     'feet': {'estimated_diameter_min': 39.494809905,
#      'estimated_diameter_max': 88.3130797061}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 12:43',
#      'epoch_date_close_approach': 1641559380000,
#      'relative_velocity': {'kilometers_per_second': '25.8115970732',
#       'kilometers_per_hour': '92921.7494633688',
#       'miles_per_hour': '57737.9614929471'},
#      'miss_distance': {'astronomical': '0.4700126636',
#       'lunar': '182.8349261404',
#       'kilometers': '70312893.347586532',
#       'miles': '43690405.9751448616'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54440311?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54440311',
#    'neo_reference_id': '54440311',
#    'name': '(2022 AY54)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54440311',
#    'absolute_magnitude_h': 30.26,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0023580607,
#      'estimated_diameter_max': 0.005272784},
#     'meters': {'estimated_diameter_min': 2.35806068,
#      'estimated_diameter_max': 5.2727839755},
#     'miles': {'estimated_diameter_min': 0.0014652305,
#      'estimated_diameter_max': 0.0032763551},
#     'feet': {'estimated_diameter_min': 7.7364198014,
#      'estimated_diameter_max': 17.2991605783}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 16:20',
#      'epoch_date_close_approach': 1641572400000,
#      'relative_velocity': {'kilometers_per_second': '17.8343002747',
#       'kilometers_per_hour': '64203.4809890064',
#       'miles_per_hour': '39893.5462845301'},
#      'miss_distance': {'astronomical': '0.0017304745',
#       'lunar': '0.6731545805',
#       'kilometers': '258875.299289315',
#       'miles': '160857.651909947'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54462805?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54462805',
#    'neo_reference_id': '54462805',
#    'name': '(2024 NM3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54462805',
#    'absolute_magnitude_h': 25.06,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0258556212,
#      'estimated_diameter_max': 0.0578149266},
#     'meters': {'estimated_diameter_min': 25.855621208,
#      'estimated_diameter_max': 57.8149266216},
#     'miles': {'estimated_diameter_min': 0.0160659332,
#      'estimated_diameter_max': 0.0359245188},
#     'feet': {'estimated_diameter_min': 84.828156284,
#      'estimated_diameter_max': 189.6815238571}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 04:42',
#      'epoch_date_close_approach': 1641530520000,
#      'relative_velocity': {'kilometers_per_second': '16.0786338517',
#       'kilometers_per_hour': '57883.0818662683',
#       'miles_per_hour': '35966.2960629599'},
#      'miss_distance': {'astronomical': '0.4069070197',
#       'lunar': '158.2868306633',
#       'kilometers': '60872423.435168039',
#       'miles': '37824369.9832713782'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54511081?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54511081',
#    'neo_reference_id': '54511081',
#    'name': '(2024 YJ7)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54511081',
#    'absolute_magnitude_h': 29.4,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0035039264,
#      'estimated_diameter_max': 0.0078350176},
#     'meters': {'estimated_diameter_min': 3.5039264111,
#      'estimated_diameter_max': 7.8350176433},
#     'miles': {'estimated_diameter_min': 0.0021772383,
#      'estimated_diameter_max': 0.0048684527},
#     'feet': {'estimated_diameter_min': 11.4958219265,
#      'estimated_diameter_max': 25.705439285}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-07',
#      'close_approach_date_full': '2022-Jan-07 22:03',
#      'epoch_date_close_approach': 1641592980000,
#      'relative_velocity': {'kilometers_per_second': '7.146525595',
#       'kilometers_per_hour': '25727.4921420703',
#       'miles_per_hour': '15986.0631034992'},
#      'miss_distance': {'astronomical': '0.0495388826',
#       'lunar': '19.2706253314',
#       'kilometers': '7410911.319140062',
#       'miles': '4604926.7604223756'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2022-01-03': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3313974?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '3313974',
#    'neo_reference_id': '3313974',
#    'name': '(2006 BV39)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3313974',
#    'absolute_magnitude_h': 29.1,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0040230458,
#      'estimated_diameter_max': 0.0089958039},
#     'meters': {'estimated_diameter_min': 4.0230457983,
#      'estimated_diameter_max': 8.9958038817},
#     'miles': {'estimated_diameter_min': 0.002499804,
#      'estimated_diameter_max': 0.0055897317},
#     'feet': {'estimated_diameter_min': 13.198969577,
#      'estimated_diameter_max': 29.5137932072}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 18:46',
#      'epoch_date_close_approach': 1641235560000,
#      'relative_velocity': {'kilometers_per_second': '22.7391653876',
#       'kilometers_per_hour': '81860.9953952192',
#       'miles_per_hour': '50865.239055435'},
#      'miss_distance': {'astronomical': '0.4926957707',
#       'lunar': '191.6586548023',
#       'kilometers': '73706237.854728409',
#       'miles': '45798932.4782096842'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3366282?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '3366282',
#    'neo_reference_id': '3366282',
#    'name': '(2007 BD)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3366282',
#    'absolute_magnitude_h': 25.4,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.022108281,
#      'estimated_diameter_max': 0.0494356193},
#     'meters': {'estimated_diameter_min': 22.1082810359,
#      'estimated_diameter_max': 49.435619262},
#     'miles': {'estimated_diameter_min': 0.0137374447,
#      'estimated_diameter_max': 0.0307178602},
#     'feet': {'estimated_diameter_min': 72.5337327539,
#      'estimated_diameter_max': 162.1903570994}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 21:43',
#      'epoch_date_close_approach': 1641246180000,
#      'relative_velocity': {'kilometers_per_second': '19.3262110391',
#       'kilometers_per_hour': '69574.3597407704',
#       'miles_per_hour': '43230.8014733693'},
#      'miss_distance': {'astronomical': '0.3772486341',
#       'lunar': '146.7497186649',
#       'kilometers': '56435592.121769367',
#       'miles': '35067450.8451645846'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3986680?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '3986680',
#    'neo_reference_id': '3986680',
#    'name': '(2020 AL3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3986680',
#    'absolute_magnitude_h': 26.2,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0152951935,
#      'estimated_diameter_max': 0.0342010925},
#     'meters': {'estimated_diameter_min': 15.2951935344,
#      'estimated_diameter_max': 34.201092472},
#     'miles': {'estimated_diameter_min': 0.0095039897,
#      'estimated_diameter_max': 0.021251567},
#     'feet': {'estimated_diameter_min': 50.1810827555,
#      'estimated_diameter_max': 112.2083122258}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 15:12',
#      'epoch_date_close_approach': 1641222720000,
#      'relative_velocity': {'kilometers_per_second': '23.2289584571',
#       'kilometers_per_hour': '83624.2504457378',
#       'miles_per_hour': '51960.8571727975'},
#      'miss_distance': {'astronomical': '0.3394091481',
#       'lunar': '132.0301586109',
#       'kilometers': '50774885.614274547',
#       'miles': '31550050.9254088686'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54106298?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54106298',
#    'neo_reference_id': '54106298',
#    'name': '(2021 BO)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54106298',
#    'absolute_magnitude_h': 32.95,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0006832112,
#      'estimated_diameter_max': 0.0015277067},
#     'meters': {'estimated_diameter_min': 0.6832111991,
#      'estimated_diameter_max': 1.5277066841},
#     'miles': {'estimated_diameter_min': 0.0004245276,
#      'estimated_diameter_max': 0.0009492726},
#     'feet': {'estimated_diameter_min': 2.2415066303,
#      'estimated_diameter_max': 5.0121611974}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 02:37',
#      'epoch_date_close_approach': 1641177420000,
#      'relative_velocity': {'kilometers_per_second': '19.5943065117',
#       'kilometers_per_hour': '70539.5034420685',
#       'miles_per_hour': '43830.5042359897'},
#      'miss_distance': {'astronomical': '0.4849352443',
#       'lunar': '188.6398100327',
#       'kilometers': '72545279.635209641',
#       'miles': '45077546.4917134058'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54160408?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54160408',
#    'neo_reference_id': '54160408',
#    'name': '(2021 LG7)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54160408',
#    'absolute_magnitude_h': 24.09,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0404161533,
#      'estimated_diameter_max': 0.0903732663},
#     'meters': {'estimated_diameter_min': 40.4161533403,
#      'estimated_diameter_max': 90.3732662579},
#     'miles': {'estimated_diameter_min': 0.0251134256,
#      'estimated_diameter_max': 0.0561553268},
#     'feet': {'estimated_diameter_min': 132.598932525,
#      'estimated_diameter_max': 296.5002268697}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 01:20',
#      'epoch_date_close_approach': 1641172800000,
#      'relative_velocity': {'kilometers_per_second': '9.2921585485',
#       'kilometers_per_hour': '33451.7707746505',
#       'miles_per_hour': '20785.629457171'},
#      'miss_distance': {'astronomical': '0.1898252773',
#       'lunar': '73.8420328697',
#       'kilometers': '28397457.156239351',
#       'miles': '17645361.6505950038'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54214719?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54214719',
#    'neo_reference_id': '54214719',
#    'name': '(2021 UW6)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54214719',
#    'absolute_magnitude_h': 22.31,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0917392059,
#      'estimated_diameter_max': 0.2051351006},
#     'meters': {'estimated_diameter_min': 91.7392059155,
#      'estimated_diameter_max': 205.1351006288},
#     'miles': {'estimated_diameter_min': 0.0570040821,
#      'estimated_diameter_max': 0.1274650026},
#     'feet': {'estimated_diameter_min': 300.9816563357,
#      'estimated_diameter_max': 673.0154435471}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 19:32',
#      'epoch_date_close_approach': 1641238320000,
#      'relative_velocity': {'kilometers_per_second': '10.9229976895',
#       'kilometers_per_hour': '39322.7916823386',
#       'miles_per_hour': '24433.6535317287'},
#      'miss_distance': {'astronomical': '0.2821718381',
#       'lunar': '109.7648450209',
#       'kilometers': '42212305.953744847',
#       'miles': '26229510.6410870086'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235431?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54235431',
#    'neo_reference_id': '54235431',
#    'name': '(2022 AL)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235431',
#    'absolute_magnitude_h': 27.21,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0096062741,
#      'estimated_diameter_max': 0.021480282},
#     'meters': {'estimated_diameter_min': 9.606274149,
#      'estimated_diameter_max': 21.4802820076},
#     'miles': {'estimated_diameter_min': 0.0059690602,
#      'estimated_diameter_max': 0.0133472243},
#     'feet': {'estimated_diameter_min': 31.5166484789,
#      'estimated_diameter_max': 70.4733684217}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 12:45',
#      'epoch_date_close_approach': 1641213900000,
#      'relative_velocity': {'kilometers_per_second': '4.1088479046',
#       'kilometers_per_hour': '14791.8524564653',
#       'miles_per_hour': '9191.0818777409'},
#      'miss_distance': {'astronomical': '0.0187571805',
#       'lunar': '7.2965432145',
#       'kilometers': '2806034.250005535',
#       'miles': '1743588.831664983'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235463?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54235463',
#    'neo_reference_id': '54235463',
#    'name': '(2022 AU)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235463',
#    'absolute_magnitude_h': 29.13,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0039678475,
#      'estimated_diameter_max': 0.0088723768},
#     'meters': {'estimated_diameter_min': 3.9678475407,
#      'estimated_diameter_max': 8.8723768253},
#     'miles': {'estimated_diameter_min': 0.0024655054,
#      'estimated_diameter_max': 0.0055130377},
#     'feet': {'estimated_diameter_min': 13.0178729253,
#      'estimated_diameter_max': 29.1088487834}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 03:05',
#      'epoch_date_close_approach': 1641179100000,
#      'relative_velocity': {'kilometers_per_second': '7.2292378449',
#       'kilometers_per_hour': '26025.2562417962',
#       'miles_per_hour': '16171.0821353539'},
#      'miss_distance': {'astronomical': '0.0021291606',
#       'lunar': '0.8282434734',
#       'kilometers': '318517.890647922',
#       'miles': '197917.8396764436'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
#    'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54235463?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235467?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54235467',
#    'neo_reference_id': '54235467',
#    'name': '(2022 AY)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235467',
#    'absolute_magnitude_h': 25.45,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0216050351,
#      'estimated_diameter_max': 0.0483103272},
#     'meters': {'estimated_diameter_min': 21.6050351196,
#      'estimated_diameter_max': 48.3103271838},
#     'miles': {'estimated_diameter_min': 0.0134247423,
#      'estimated_diameter_max': 0.0300186363},
#     'feet': {'estimated_diameter_min': 70.8826634219,
#      'estimated_diameter_max': 158.4984538377}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 11:13',
#      'epoch_date_close_approach': 1641208380000,
#      'relative_velocity': {'kilometers_per_second': '12.2317612796',
#       'kilometers_per_hour': '44034.3406065262',
#       'miles_per_hour': '27361.2268063162'},
#      'miss_distance': {'astronomical': '0.0518218428',
#       'lunar': '20.1586968492',
#       'kilometers': '7752437.302354836',
#       'miles': '4817141.1658792968'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235479?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54235479',
#    'neo_reference_id': '54235479',
#    'name': '(2022 AL1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235479',
#    'absolute_magnitude_h': 26.28,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0147419515,
#      'estimated_diameter_max': 0.0329640056},
#     'meters': {'estimated_diameter_min': 14.7419514504,
#      'estimated_diameter_max': 32.9640055641},
#     'miles': {'estimated_diameter_min': 0.0091602211,
#      'estimated_diameter_max': 0.0204828771},
#     'feet': {'estimated_diameter_min': 48.3659839966,
#      'estimated_diameter_max': 108.1496280151}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 20:50',
#      'epoch_date_close_approach': 1641243000000,
#      'relative_velocity': {'kilometers_per_second': '8.8316429811',
#       'kilometers_per_hour': '31793.9147319844',
#       'miles_per_hour': '19755.5021844377'},
#      'miss_distance': {'astronomical': '0.0437554459',
#       'lunar': '17.0208684551',
#       'kilometers': '6545721.507540233',
#       'miles': '4067322.7405238954'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235524?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54235524',
#    'neo_reference_id': '54235524',
#    'name': '(2022 AO1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235524',
#    'absolute_magnitude_h': 29.6,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0031956189,
#      'estimated_diameter_max': 0.007145621},
#     'meters': {'estimated_diameter_min': 3.1956188672,
#      'estimated_diameter_max': 7.1456210173},
#     'miles': {'estimated_diameter_min': 0.0019856649,
#      'estimated_diameter_max': 0.0044400817},
#     'feet': {'estimated_diameter_min': 10.4843142043,
#      'estimated_diameter_max': 23.4436392583}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 16:19',
#      'epoch_date_close_approach': 1641226740000,
#      'relative_velocity': {'kilometers_per_second': '14.0833111554',
#       'kilometers_per_hour': '50699.9201593154',
#       'miles_per_hour': '31502.9587234369'},
#      'miss_distance': {'astronomical': '0.0023236311',
#       'lunar': '0.9038924979',
#       'kilometers': '347610.263225757',
#       'miles': '215995.0017471666'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
#    'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54235524?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235674?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54235674',
#    'neo_reference_id': '54235674',
#    'name': '(2022 AZ2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235674',
#    'absolute_magnitude_h': 27.75,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0074912618,
#      'estimated_diameter_max': 0.0167509707},
#     'meters': {'estimated_diameter_min': 7.4912618313,
#      'estimated_diameter_max': 16.750970692},
#     'miles': {'estimated_diameter_min': 0.0046548529,
#      'estimated_diameter_max': 0.0104085674},
#     'feet': {'estimated_diameter_min': 24.5776314666,
#      'estimated_diameter_max': 54.9572546853}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 19:34',
#      'epoch_date_close_approach': 1641238440000,
#      'relative_velocity': {'kilometers_per_second': '9.77217224',
#       'kilometers_per_hour': '35179.8200639127',
#       'miles_per_hour': '21859.3720836018'},
#      'miss_distance': {'astronomical': '0.0131463183',
#       'lunar': '5.1139178187',
#       'kilometers': '1966661.216022021',
#       'miles': '1222026.6135090498'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54243723?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54243723',
#    'neo_reference_id': '54243723',
#    'name': '(2022 BX5)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54243723',
#    'absolute_magnitude_h': 29.04,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0041357566,
#      'estimated_diameter_max': 0.009247833},
#     'meters': {'estimated_diameter_min': 4.1357566488,
#      'estimated_diameter_max': 9.2478330051},
#     'miles': {'estimated_diameter_min': 0.0025698392,
#      'estimated_diameter_max': 0.0057463352},
#     'feet': {'estimated_diameter_min': 13.5687558437,
#      'estimated_diameter_max': 30.3406604365}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 20:44',
#      'epoch_date_close_approach': 1641242640000,
#      'relative_velocity': {'kilometers_per_second': '0.6500953649',
#       'kilometers_per_hour': '2340.343313525',
#       'miles_per_hour': '1454.1983216733'},
#      'miss_distance': {'astronomical': '0.0153014363',
#       'lunar': '5.9522587207',
#       'kilometers': '2289062.278420681',
#       'miles': '1422357.3442241578'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54330582?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54330582',
#    'neo_reference_id': '54330582',
#    'name': '(2022 WQ9)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54330582',
#    'absolute_magnitude_h': 28.73,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.004770402,
#      'estimated_diameter_max': 0.0106669431},
#     'meters': {'estimated_diameter_min': 4.7704019801,
#      'estimated_diameter_max': 10.6669431075},
#     'miles': {'estimated_diameter_min': 0.0029641894,
#      'estimated_diameter_max': 0.0066281291},
#     'feet': {'estimated_diameter_min': 15.6509256325,
#      'estimated_diameter_max': 34.996533625}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 12:00',
#      'epoch_date_close_approach': 1641211200000,
#      'relative_velocity': {'kilometers_per_second': '5.1073246446',
#       'kilometers_per_hour': '18386.3687206673',
#       'miles_per_hour': '11424.5744975724'},
#      'miss_distance': {'astronomical': '0.1971316323',
#       'lunar': '76.6842049647',
#       'kilometers': '29490472.301703201',
#       'miles': '18324529.7685421338'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54415896?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54415896',
#    'neo_reference_id': '54415896',
#    'name': '(2023 XU10)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54415896',
#    'absolute_magnitude_h': 27.66,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0078082728,
#      'estimated_diameter_max': 0.0174598287},
#     'meters': {'estimated_diameter_min': 7.8082727749,
#      'estimated_diameter_max': 17.4598287116},
#     'miles': {'estimated_diameter_min': 0.0048518343,
#      'estimated_diameter_max': 0.0108490312},
#     'feet': {'estimated_diameter_min': 25.6176936508,
#      'estimated_diameter_max': 57.2829044301}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-03',
#      'close_approach_date_full': '2022-Jan-03 07:21',
#      'epoch_date_close_approach': 1641194460000,
#      'relative_velocity': {'kilometers_per_second': '14.9301728065',
#       'kilometers_per_hour': '53748.6221034389',
#       'miles_per_hour': '33397.303550884'},
#      'miss_distance': {'astronomical': '0.2820202319',
#       'lunar': '109.7058702091',
#       'kilometers': '42189625.989146053',
#       'miles': '26215417.9645714114'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
# ...
#      'estimated_diameter_max': 0.0927664547},
#     'feet': {'estimated_diameter_min': 219.0483710172,
#      'estimated_diameter_max': 489.807047955}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 05:02',
#      'epoch_date_close_approach': 1641099720000,
#      'relative_velocity': {'kilometers_per_second': '20.4077209528',
#       'kilometers_per_hour': '73467.7954302229',
#       'miles_per_hour': '45650.0309994071'},
#      'miss_distance': {'astronomical': '0.495238863',
#       'lunar': '192.647917707',
#       'kilometers': '74086679.04602181',
#       'miles': '46035327.672688578'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3826839?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '3826839',
#    'neo_reference_id': '3826839',
#    'name': '(2018 PR23)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3826839',
#    'absolute_magnitude_h': 25.4,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.022108281,
#      'estimated_diameter_max': 0.0494356193},
#     'meters': {'estimated_diameter_min': 22.1082810359,
#      'estimated_diameter_max': 49.435619262},
#     'miles': {'estimated_diameter_min': 0.0137374447,
#      'estimated_diameter_max': 0.0307178602},
#     'feet': {'estimated_diameter_min': 72.5337327539,
#      'estimated_diameter_max': 162.1903570994}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 02:04',
#      'epoch_date_close_approach': 1641089040000,
#      'relative_velocity': {'kilometers_per_second': '8.4332699552',
#       'kilometers_per_hour': '30359.7718385923',
#       'miles_per_hour': '18864.3815627076'},
#      'miss_distance': {'astronomical': '0.4832391866',
#       'lunar': '187.9800435874',
#       'kilometers': '72291553.015892542',
#       'miles': '44919888.0811873996'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54053824?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54053824',
#    'neo_reference_id': '54053824',
#    'name': '(2020 RG2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54053824',
#    'absolute_magnitude_h': 27.1,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0101054342,
#      'estimated_diameter_max': 0.0225964377},
#     'meters': {'estimated_diameter_min': 10.1054341542,
#      'estimated_diameter_max': 22.5964377109},
#     'miles': {'estimated_diameter_min': 0.0062792237,
#      'estimated_diameter_max': 0.0140407711},
#     'feet': {'estimated_diameter_min': 33.1543125905,
#      'estimated_diameter_max': 74.1352966996}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 19:38',
#      'epoch_date_close_approach': 1641152280000,
#      'relative_velocity': {'kilometers_per_second': '14.9839822861',
#       'kilometers_per_hour': '53942.3362298765',
#       'miles_per_hour': '33517.6699757252'},
#      'miss_distance': {'astronomical': '0.394202746',
#       'lunar': '153.344868194',
#       'kilometers': '58971891.14975102',
#       'miles': '36643433.981843276'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54143421?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54143421',
#    'neo_reference_id': '54143421',
#    'name': '(2021 JG1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54143421',
#    'absolute_magnitude_h': 24.76,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0296862251,
#      'estimated_diameter_max': 0.0663804174},
#     'meters': {'estimated_diameter_min': 29.686225126,
#      'estimated_diameter_max': 66.3804173771},
#     'miles': {'estimated_diameter_min': 0.0184461594,
#      'estimated_diameter_max': 0.0412468663},
#     'feet': {'estimated_diameter_min': 97.3957548424,
#      'estimated_diameter_max': 217.7835285475}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 03:22',
#      'epoch_date_close_approach': 1641093720000,
#      'relative_velocity': {'kilometers_per_second': '9.0784070708',
#       'kilometers_per_hour': '32682.2654550162',
#       'miles_per_hour': '20307.4887767571'},
#      'miss_distance': {'astronomical': '0.4900141572',
#       'lunar': '190.6155071508',
#       'kilometers': '73305074.186965164',
#       'miles': '45549660.9339367032'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54203032?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54203032',
#    'neo_reference_id': '54203032',
#    'name': '(2021 TK3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54203032',
#    'absolute_magnitude_h': 20.05,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2597496533,
#      'estimated_diameter_max': 0.580817882},
#     'meters': {'estimated_diameter_min': 259.7496533301,
#      'estimated_diameter_max': 580.817881978},
#     'miles': {'estimated_diameter_min': 0.1614009018,
#      'estimated_diameter_max': 0.3609033881},
#     'feet': {'estimated_diameter_min': 852.1970526314,
#      'estimated_diameter_max': 1905.5705399087}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 09:23',
#      'epoch_date_close_approach': 1641115380000,
#      'relative_velocity': {'kilometers_per_second': '7.790798039',
#       'kilometers_per_hour': '28046.8729404888',
#       'miles_per_hour': '17427.2361334943'},
#      'miss_distance': {'astronomical': '0.3430354198',
#       'lunar': '133.4407783022',
#       'kilometers': '51317368.136635826',
#       'miles': '31887133.9340573588'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54231688?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54231688',
#    'neo_reference_id': '54231688',
#    'name': '(2021 YK)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54231688',
#    'absolute_magnitude_h': 27.35,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0090064777,
#      'estimated_diameter_max': 0.0201390963},
#     'meters': {'estimated_diameter_min': 9.0064776702,
#      'estimated_diameter_max': 20.1390963084},
#     'miles': {'estimated_diameter_min': 0.005596364,
#      'estimated_diameter_max': 0.0125138504},
#     'feet': {'estimated_diameter_min': 29.5488121994,
#      'estimated_diameter_max': 66.0731527323}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 16:03',
#      'epoch_date_close_approach': 1641139380000,
#      'relative_velocity': {'kilometers_per_second': '7.0444404315',
#       'kilometers_per_hour': '25359.9855533708',
#       'miles_per_hour': '15757.7088012042'},
#      'miss_distance': {'astronomical': '0.0012691966',
#       'lunar': '0.4937174774',
#       'kilometers': '189869.107971242',
#       'miles': '117979.1929254596'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
#    'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54231688?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235436?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54235436',
#    'neo_reference_id': '54235436',
#    'name': '(2022 AQ)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235436',
#    'absolute_magnitude_h': 27.04,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.010388551,
#      'estimated_diameter_max': 0.0232295062},
#     'meters': {'estimated_diameter_min': 10.3885510102,
#      'estimated_diameter_max': 23.2295062464},
#     'miles': {'estimated_diameter_min': 0.0064551443,
#      'estimated_diameter_max': 0.0144341415},
#     'feet': {'estimated_diameter_min': 34.0831736962,
#      'estimated_diameter_max': 76.2122932736}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 15:58',
#      'epoch_date_close_approach': 1641139080000,
#      'relative_velocity': {'kilometers_per_second': '11.4430529094',
#       'kilometers_per_hour': '41194.9904738353',
#       'miles_per_hour': '25596.965053034'},
#      'miss_distance': {'astronomical': '0.0192982031',
#       'lunar': '7.5070010059',
#       'kilometers': '2886970.078587397',
#       'miles': '1793880.0235121986'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235525?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54235525',
#    'neo_reference_id': '54235525',
#    'name': '(2022 AP1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235525',
#    'absolute_magnitude_h': 28.39,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0055789822,
#      'estimated_diameter_max': 0.0124749835},
#     'meters': {'estimated_diameter_min': 5.5789822107,
#      'estimated_diameter_max': 12.4749834683},
#     'miles': {'estimated_diameter_min': 0.0034666178,
#      'estimated_diameter_max': 0.007751593},
#     'feet': {'estimated_diameter_min': 18.3037479961,
#      'estimated_diameter_max': 40.9284247622}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 16:56',
#      'epoch_date_close_approach': 1641142560000,
#      'relative_velocity': {'kilometers_per_second': '10.640214595',
#       'kilometers_per_hour': '38304.772541869',
#       'miles_per_hour': '23801.0960274741'},
#      'miss_distance': {'astronomical': '0.0012072168',
#       'lunar': '0.4696073352',
#       'kilometers': '180597.061908216',
#       'miles': '112217.8106607408'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
#    'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54235525?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54235670?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54235670',
#    'neo_reference_id': '54235670',
#    'name': '(2022 AV2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54235670',
#    'absolute_magnitude_h': 24.81,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0290104841,
#      'estimated_diameter_max': 0.0648694146},
#     'meters': {'estimated_diameter_min': 29.0104841428,
#      'estimated_diameter_max': 64.8694146035},
#     'miles': {'estimated_diameter_min': 0.0180262735,
#      'estimated_diameter_max': 0.040307973},
#     'feet': {'estimated_diameter_min': 95.1787567951,
#      'estimated_diameter_max': 212.8261702077}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 09:40',
#      'epoch_date_close_approach': 1641116400000,
#      'relative_velocity': {'kilometers_per_second': '11.4458122646',
#       'kilometers_per_hour': '41204.9241523926',
#       'miles_per_hour': '25603.1374545797'},
#      'miss_distance': {'astronomical': '0.0663840677',
#       'lunar': '25.8234023353',
#       'kilometers': '9930915.129855799',
#       'miles': '6170784.5186120662'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54240279?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54240279',
#    'neo_reference_id': '54240279',
#    'name': '(2022 BF2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54240279',
#    'absolute_magnitude_h': 23.02,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0661538275,
#      'estimated_diameter_max': 0.1479244553},
#     'meters': {'estimated_diameter_min': 66.1538275199,
#      'estimated_diameter_max': 147.9244553064},
#     'miles': {'estimated_diameter_min': 0.04110607,
#      'estimated_diameter_max': 0.0919159667},
#     'feet': {'estimated_diameter_min': 217.0401234805,
#      'estimated_diameter_max': 485.3164699474}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 09:44',
#      'epoch_date_close_approach': 1641116640000,
#      'relative_velocity': {'kilometers_per_second': '13.6716305429',
#       'kilometers_per_hour': '49217.8699543345',
#       'miles_per_hour': '30582.0703613475'},
#      'miss_distance': {'astronomical': '0.1396774323',
#       'lunar': '54.3345211647',
#       'kilometers': '20895446.359149201',
#       'miles': '12983828.2994569338'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54374712?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54374712',
#    'neo_reference_id': '54374712',
#    'name': '(2023 NC)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54374712',
#    'absolute_magnitude_h': 23.73,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0477040198,
#      'estimated_diameter_max': 0.1066694311},
#     'meters': {'estimated_diameter_min': 47.7040198012,
#      'estimated_diameter_max': 106.6694310755},
#     'miles': {'estimated_diameter_min': 0.0296418945,
#      'estimated_diameter_max': 0.0662812911},
#     'feet': {'estimated_diameter_min': 156.5092563246,
#      'estimated_diameter_max': 349.9653362497}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 12:35',
#      'epoch_date_close_approach': 1641126900000,
#      'relative_velocity': {'kilometers_per_second': '12.9390279932',
#       'kilometers_per_hour': '46580.5007753576',
#       'miles_per_hour': '28943.3117178882'},
#      'miss_distance': {'astronomical': '0.2914198022',
#       'lunar': '113.3623030558',
#       'kilometers': '43595781.684941314',
#       'miles': '27089162.5978615732'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54469019?api_key=nbx0DVssdnFFLxJ6EbWFK37sLAhyDNpd5Q5lkMgV'},
#    'id': '54469019',
#    'neo_reference_id': '54469019',
#    'name': '(2024 RT5)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54469019',
#    'absolute_magnitude_h': 23.92,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0437074004,
#      'estimated_diameter_max': 0.0977327184},
#     'meters': {'estimated_diameter_min': 43.7074004031,
#      'estimated_diameter_max': 97.732718421},
#     'miles': {'estimated_diameter_min': 0.0271585111,
#      'estimated_diameter_max': 0.060728277},
#     'feet': {'estimated_diameter_min': 143.3969875384,
#      'estimated_diameter_max': 320.6454119044}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2022-01-02',
#      'close_approach_date_full': '2022-Jan-02 13:22',
#      'epoch_date_close_approach': 1641129720000,
#      'relative_velocity': {'kilometers_per_second': '16.2228330993',
#       'kilometers_per_hour': '58402.199157368',
#       'miles_per_hour': '36288.8553597546'},
#      'miss_distance': {'astronomical': '0.4625825018',
#       'lunar': '179.9445932002',
#       'kilometers': '69201356.968551166',
#       'miles': '42999729.2963154508'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}]}

# %%
res['near_earth_objects'].keys()
# Out:
# dict_keys(['2022-01-07', '2022-01-03', '2022-01-04', '2022-01-05', '2022-01-06', '2022-01-01', '2022-01-02'])

# %%
for x in res['near_earth_objects'].keys():
    my_object = res['near_earth_objects'][x]
    print(f'on this day: {x}, we have this many objects near earth: {len(my_object)}')
# Out:
# on this day: 2022-01-07, we have this many objects near earth: 20
# on this day: 2022-01-03, we have this many objects near earth: 16
# on this day: 2022-01-04, we have this many objects near earth: 8
# on this day: 2022-01-05, we have this many objects near earth: 14
# on this day: 2022-01-06, we have this many objects near earth: 21
# on this day: 2022-01-01, we have this many objects near earth: 22
# on this day: 2022-01-02, we have this many objects near earth: 14

# %% [markdown]
# **Question:** How many near earth objects were there on January 3?

# %%
my_list = ['A','b','c','d','e','f']

# %%
len(my_list)
# Out:
# 6

# %%
my_list[2]
# Out:
# 'c'

# %%
# Your Code Here
len(res['near_earth_objects']['2022-01-03'])#[2]['estimated_diameter']['meters']['estimated_diameter_max']
# Out:
# 16

# %% [markdown]
# **Question:** Is the first returned result for January 3 potentially hazardous (as indicated by the `is_potentially_hazardous_asteroid` field)?

# %%
# Your Code Here
res['near_earth_objects']['2022-01-03'][0]['is_potentially_hazardous_asteroid']
# Out:
# False

# %% [markdown]
# **Question:** What was the relative velocity, in miles per hour of the first object returned for January 3?

# %%
# Your Code Here
res['near_earth_objects']['2022-01-03'][0]['close_approach_data'][0]['relative_velocity']['miles_per_hour']
# Out:
# '50865.239055435'

# %% [markdown]
# The for loop below iterates over the data returned and pulls out information for each asteroid. It then saves the information to lists, that are used for making a scatter plot of the asteroids.

# %%
max_diam = []
hazardous = []
miss_dist = []
for day, objs in res['near_earth_objects'].items():
    for obj in objs:
        max_diam.append(float(obj['estimated_diameter']['miles']['estimated_diameter_max']))
        hazardous.append(obj['is_potentially_hazardous_asteroid'])
        miss_dist.append(float(obj['close_approach_data'][0]['miss_distance']['miles']))

plt.figure(figsize = (17, 10))
plt.scatter(max_diam, miss_dist, c = hazardous)
plt.xlabel('max diameter (miles)')
plt.ylabel('miss distance (miles)');

# %% [markdown]
# If you want to work with the response from an API using _pandas_, you'll want to convert it to a DataFrame. In some circumstances, you can easily convert a json to a DataFrame, but in other cases, you have to do a little bit of work.

# %%
import pandas as pd

# %% [markdown]
# The easiest case is when you have a list of dictionaries. Here, you can simply use the `DataFrame` constructor. Let's see how this works using one of the days. If you wanted to get all of the results into a single DataFrame, you could iterate through and concatenate.

# %%
response.json()['near_earth_objects']['2022-01-07'][0]['close_approach_data'][0]
# Out:
# {'close_approach_date': '2022-01-07',
#  'close_approach_date_full': '2022-Jan-07 12:09',
#  'epoch_date_close_approach': 1641557340000,
#  'relative_velocity': {'kilometers_per_second': '10.0478001196',
#   'kilometers_per_hour': '36172.0804304837',
#   'miles_per_hour': '22475.9240874858'},
#  'miss_distance': {'astronomical': '0.1338706738',
#   'lunar': '52.0756921082',
#   'kilometers': '20026767.655944806',
#   'miles': '12444056.3828420828'},
#  'orbiting_body': 'Earth'}

# %%
#pd.DataFrame(response.json()['near_earth_objects']['2022-01-07'])#.head(2)

# %% [markdown]
# You'll notice that we still have dictionaries in some of the columns. This can be remedied using the `json_normalize` function.

# %%
pd.json_normalize(response.json()['near_earth_objects']['2022-01-07']).head(2)
# Out:
#         id neo_reference_id                 name  \
# 0  2494697          2494697   494697 (2004 SW55)
# 1  2496860          2496860  496860 (1999 XL136)
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 20.77
# 1  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.67
#
#    is_potentially_hazardous_asteroid  \
# 0                               True
# 1                               True
#
#                                  close_approach_data  is_sentry_object  \
# 0  [{'close_approach_date': '2022-01-07', 'close_...             False
# 1  [{'close_approach_date': '2022-01-07', 'close_...             False
#
#                                           links.self  \
# 0  http://api.nasa.gov/neo/rest/v1/neo/2494697?ap...
# 1  http://api.nasa.gov/neo/rest/v1/neo/2496860?ap...
#
#    estimated_diameter.kilometers.estimated_diameter_min  \
# 0                                           0.186447
# 1                                           0.309425
#
#    estimated_diameter.kilometers.estimated_diameter_max  \
# 0                                           0.416908
# 1                                           0.691895
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        186.446818
# 1                                        309.424699
#
#    estimated_diameter.meters.estimated_diameter_max  \
# 0                                         416.90776
# 1                                         691.89466
#
#    estimated_diameter.miles.estimated_diameter_min  \
# 0                                         0.115853
# 1                                         0.192268
#
#    estimated_diameter.miles.estimated_diameter_max  \
# 0                                         0.259054
# 1                                         0.429923
#
#    estimated_diameter.feet.estimated_diameter_min  \
# 0                                      611.702179
# 1                                     1015.172928
#
#    estimated_diameter.feet.estimated_diameter_max sentry_data
# 0                                     1367.807655         NaN
# 1                                     2269.995676         NaN

# %% [markdown]
# This almost does it, but the `close_approach_data` column contains a list, which `json_normalize` can't handle. To fix this, we can use the `explode` method which will unpack the list across multiple columns, if needed.

# %%
# response_df = pd.json_normalize(response.json()['near_earth_objects']['2022-01-07'])
# response_df.explode('close_approach_data').head(2)

# %% [markdown]
# Once exploded, you can use the `json_normalize` function again.

# %%
pd.json_normalize(response_df.explode('close_approach_data')['close_approach_data']).head(2)
# Out:
#   close_approach_date close_approach_date_full  epoch_date_close_approach  \
# 0          2022-01-07        2022-Jan-07 12:09              1641557340000
# 1          2022-01-07        2022-Jan-07 02:07              1641521220000
#
#   orbiting_body relative_velocity.kilometers_per_second  \
# 0         Earth                           10.0478001196
# 1         Earth                           16.7624360583
#
#   relative_velocity.kilometers_per_hour relative_velocity.miles_per_hour  \
# 0                      36172.0804304837                 22475.9240874858
# 1                      60344.7698097014                 37495.8932187003
#
#   miss_distance.astronomical miss_distance.lunar miss_distance.kilometers  \
# 0               0.1338706738       52.0756921082       20026767.655944806
# 1               0.0895472705       34.8338882245       13396080.931113835
#
#    miss_distance.miles
# 0  12444056.3828420828
# 1    8323938.704427523

# %% [markdown]
# And finally, you can concatenate the two pieces together.

# %%
pd.concat([
    response_df.explode('close_approach_data').drop(columns = ['close_approach_data']),
    pd.json_normalize(response_df.explode('close_approach_data')['close_approach_data'])
], axis = 1).head(2)
# Out:
#         id neo_reference_id                 name  \
# 0  2494697          2494697   494697 (2004 SW55)
# 1  2496860          2496860  496860 (1999 XL136)
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 20.77
# 1  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.67
#
#    is_potentially_hazardous_asteroid  is_sentry_object  \
# 0                               True             False
# 1                               True             False
#
#                                           links.self  \
# 0  http://api.nasa.gov/neo/rest/v1/neo/2494697?ap...
# 1  http://api.nasa.gov/neo/rest/v1/neo/2496860?ap...
#
#    estimated_diameter.kilometers.estimated_diameter_min  \
# 0                                           0.186447
# 1                                           0.309425
#
#    estimated_diameter.kilometers.estimated_diameter_max  ...  \
# 0                                           0.416908     ...
# 1                                           0.691895     ...
#
#    close_approach_date_full  epoch_date_close_approach  orbiting_body  \
# 0         2022-Jan-07 12:09              1641557340000          Earth
# 1         2022-Jan-07 02:07              1641521220000          Earth
#
#    relative_velocity.kilometers_per_second  \
# 0                            10.0478001196
# 1                            16.7624360583
#
#    relative_velocity.kilometers_per_hour  relative_velocity.miles_per_hour  \
# 0                       36172.0804304837                  22475.9240874858
# 1                       60344.7698097014                  37495.8932187003
#
#   miss_distance.astronomical miss_distance.lunar miss_distance.kilometers  \
# 0               0.1338706738       52.0756921082       20026767.655944806
# 1               0.0895472705       34.8338882245       13396080.931113835
#
#    miss_distance.miles
# 0  12444056.3828420828
# 1    8323938.704427523
#
# [2 rows x 28 columns]

# %%
df = pd.concat([
    response_df.explode('close_approach_data').drop(columns = ['close_approach_data']),
    pd.json_normalize(response_df.explode('close_approach_data')['close_approach_data'])
], axis = 1)

# %%
df.head()##[['relative_velocity.miles_per_hour']]
# Out:
#         id neo_reference_id                 name  \
# 0  2494697          2494697   494697 (2004 SW55)
# 1  2496860          2496860  496860 (1999 XL136)
# 2  3311963          3311963           (2006 AL4)
# 3  3401388          3401388            (2008 CO)
# 4  3827355          3827355           (2018 RH3)
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 20.77
# 1  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.67
# 2  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 24.92
# 3  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 22.60
# 4  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 26.10
#
#    is_potentially_hazardous_asteroid  is_sentry_object  \
# 0                               True             False
# 1                               True             False
# 2                              False             False
# 3                              False             False
# 4                              False              True
#
#                                           links.self  \
# 0  http://api.nasa.gov/neo/rest/v1/neo/2494697?ap...
# 1  http://api.nasa.gov/neo/rest/v1/neo/2496860?ap...
# 2  http://api.nasa.gov/neo/rest/v1/neo/3311963?ap...
# 3  http://api.nasa.gov/neo/rest/v1/neo/3401388?ap...
# 4  http://api.nasa.gov/neo/rest/v1/neo/3827355?ap...
#
#    estimated_diameter.kilometers.estimated_diameter_min  \
# 0                                           0.186447
# 1                                           0.309425
# 2                                           0.027578
# 3                                           0.080270
# 4                                           0.016016
#
#    estimated_diameter.kilometers.estimated_diameter_max  ...  \
# 0                                           0.416908     ...
# 1                                           0.691895     ...
# 2                                           0.061665     ...
# 3                                           0.179490     ...
# 4                                           0.035813     ...
#
#    close_approach_date_full  epoch_date_close_approach  orbiting_body  \
# 0         2022-Jan-07 12:09              1641557340000          Earth
# 1         2022-Jan-07 02:07              1641521220000          Earth
# 2         2022-Jan-07 14:45              1641566700000          Earth
# 3         2022-Jan-07 07:54              1641542040000          Earth
# 4         2022-Jan-07 06:02              1641535320000          Earth
#
#    relative_velocity.kilometers_per_second  \
# 0                            10.0478001196
# 1                            16.7624360583
# 2                             9.4579600698
# 3                             4.4645655825
# 4                            16.2331353604
#
#    relative_velocity.kilometers_per_hour  relative_velocity.miles_per_hour  \
# 0                       36172.0804304837                  22475.9240874858
# 1                       60344.7698097014                  37495.8932187003
# 2                       34048.6562512758                   21156.510880133
# 3                       16072.4360970133                   9986.7867515025
# 4                        58439.287297512                  36311.9004877235
#
#   miss_distance.astronomical miss_distance.lunar miss_distance.kilometers  \
# 0               0.1338706738       52.0756921082       20026767.655944806
# 1               0.0895472705       34.8338882245       13396080.931113835
# 2                0.095183198        37.026264022        14239203.68058826
# 3               0.2067861693       80.4398198577       30934770.472739391
# 4               0.2550666419       99.2209236991       38157426.336292753
#
#    miss_distance.miles
# 0  12444056.3828420828
# 1    8323938.704427523
# 2    8847830.887747588
# 3  19221975.0369339558
# 4  23709925.2815278714
#
# [5 rows x 28 columns]

# %% [markdown]
# Let's try another `endpoint` from NASA. This time copy the endpoint from the **APOD** (Astronomy Picture of the Day) section.
#
# Fill in the endpoint and parameters in order to retrieve the image for January 1, 2019.

# %%
endpoint = ''

params = {

}

# %%
endpoint = 'https://api.nasa.gov/planetary/apod'

params = {
    'api_key' : api_key,
    #'concept_tags' : True,
    'date' : '2025-09-01'
}

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'date': '2025-09-01',
#  'explanation': "Its surface is the most densely cratered in the Solar System -- but what's inside?  Jupiter's moon Callisto is a battered ball of dirty ice that is slightly smaller than the planet Mercury. It was visited by NASA's Galileo spacecraft in the 1990s and 2000s, but the recently reprocessed featured image is from a flyby of NASA's Voyager 2 in 1979.  The moon would appear darker if it weren't for the tapestry of light-colored fractured surface ice created by eons of impacts. The interior of Callisto is potentially even more interesting because therein might lie an internal layer of liquid water. This potential underground sea is a candidate to harbor life -- similar with sister moons Europa and Ganymede.  Callisto is larger than Luna, Earth's Moon, and even with its high ice content is still more massive. ESA's JUICE and NASA's Europa Clipper missions are now headed out to Jupiter to better investigate its largest moons.",
#  'hdurl': 'https://apod.nasa.gov/apod/image/2509/Callisto_Voyager2Gill_1602.jpg',
#  'media_type': 'image',
#  'service_version': 'v1',
#  'title': 'Callisto: Dirty Battered Iceball',
#  'url': 'https://apod.nasa.gov/apod/image/2509/Callisto_Voyager2Gill_960.jpg'}

# %% [markdown]
# Finally, let's grab the image url so that we can retrieve the actual image.

# %%
image_response = requests.get(response.json()['url'])

# %% [markdown]
# For image responses, we don't want to look at the text or json, but instead take the content. We'll now use the `.content` attribute from the response to render an image.

# %%
from IPython.display import Image

# %%
Image(image_response.content)
